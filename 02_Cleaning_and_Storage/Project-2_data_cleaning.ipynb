# %% [markdown]
# # Data Cleaning for Visualization Dashboard Project

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sqlalchemy import create_engine
import geojson
import json
import os

# %% [markdown]
# ### Set file locations

# %%
# input file containing dataset as acquired
superfund_sites_file = "../01_Data_Acquisition/priorities_list_full.json"

# csv file for inspecting the results of the initial data import
import_inspection_file = "verification_files/priorities_list_full.csv"

# csv file for inspecting the results of data cleaning
cleaning_inspection_file = "verification_files/priorities_list_full_cleaned.csv"

# csv file for inspecting data prepped for visualization
viz_inspection_file = "verification_files/superfund_site_data.csv"

# geojson output file for visualizations
geojson_output_file = "../03_Dataset/superfund_site_geojson.js"

# %% [markdown]
# ## Exploring the Dataset

# %% [markdown]
# ### Bring in the JSON Dataset

# %%
superfund_sites_df = pd.read_json(superfund_sites_file)

# %% [markdown]
# ### Create a list of column names
# We copy this list over to a spreadsheet to compare it with simialr lists from the census data files. Notably, the JSON file includes both census block and tract IDs, along with the full FIPS code. It is especially convenient that the JSON file includes data of particular interest, including the latidtude and longitude of each site, the site ID, the site 'score', and socioeconomic values for the population within the same census boundaries.

# %%
superfund_column_names = list(superfund_sites_df.columns.values)
superfund_column_names
# Out:
# ['FIPS_Full',
#  'address',
#  'city',
#  'date_added',
#  'federal_facility_ind',
#  'federal_register_url',
#  'geocode_source',
#  'latitude',
#  'longitude',
#  'site_epa_id',
#  'site_name',
#  'site_narrative_url',
#  'site_progress_url',
#  'site_score',
#  'text',
#  'FIPS_Block_Group',
#  'State',
#  'State_name',
#  'County',
#  'County_name',
#  'Tract',
#  'Block_Group',
#  'Flag',
#  'LAND_AREA',
#  'AIAN_LAND',
#  'URBANIZED_AREA_POP_CEN_2010',
#  'URBAN_CLUSTER_POP_CEN_2010',
#  'RURAL_POP_CEN_2010',
#  'Tot_Population_CEN_2010',
#  'Tot_Population_ACS_09_13',
#  'Tot_Population_ACSMOE_09_13',
#  'Males_CEN_2010',
#  'Males_ACS_09_13',
#  'Males_ACSMOE_09_13',
#  'Females_CEN_2010',
#  'Females_ACS_09_13',
#  'Females_ACSMOE_09_13',
#  'Pop_under_5_CEN_2010',
#  'Pop_under_5_ACS_09_13',
#  'Pop_under_5_ACSMOE_09_13',
#  'Pop_5_17_CEN_2010',
#  'Pop_5_17_ACS_09_13',
#  'Pop_5_17_ACSMOE_09_13',
#  'Pop_18_24_CEN_2010',
#  'Pop_18_24_ACS_09_13',
#  'Pop_18_24_ACSMOE_09_13',
#  'Pop_25_44_CEN_2010',
#  'Pop_25_44_ACS_09_13',
#  'Pop_25_44_ACSMOE_09_13',
#  'Pop_45_64_CEN_2010',
#  'Pop_45_64_ACS_09_13',
#  'Pop_45_64_ACSMOE_09_13',
#  'Pop_65plus_CEN_2010',
#  'Pop_65plus_ACS_09_13',
#  'Pop_65plus_ACSMOE_09_13',
#  'Tot_GQ_CEN_2010',
#  'Inst_GQ_CEN_2010',
#  'Non_Inst_GQ_CEN_2010',
#  'Hispanic_CEN_2010',
#  'Hispanic_ACS_09_13',
#  'Hispanic_ACSMOE_09_13',
#  'NH_White_alone_CEN_2010',
#  'NH_White_alone_ACS_09_13',
#  'NH_White_alone_ACSMOE_09_13',
#  'NH_Blk_alone_CEN_2010',
#  'NH_Blk_alone_ACS_09_13',
#  'NH_Blk_alone_ACSMOE_09_13',
#  'NH_AIAN_alone_CEN_2010',
#  'NH_AIAN_alone_ACS_09_13',
#  'NH_AIAN_alone_ACSMOE_09_13',
#  'NH_Asian_alone_CEN_2010',
#  'NH_Asian_alone_ACS_09_13',
#  'NH_Asian_alone_ACSMOE_09_13',
#  'NH_NHOPI_alone_CEN_2010',
#  'NH_NHOPI_alone_ACS_09_13',
#  'NH_NHOPI_alone_ACSMOE_09_13',
#  'NH_SOR_alone_CEN_2010',
#  'NH_SOR_alone_ACS_09_13',
#  'NH_SOR_alone_ACSMOE_09_13',
#  'Pop_5yrs_Over_ACS_09_13',
#  'Pop_5yrs_Over_ACSMOE_09_13',
#  'Othr_Lang_ACS_09_13',
#  'Othr_Lang_ACSMOE_09_13',
#  'Pop_25yrs_Over_ACS_09_13',
#  'Pop_25yrs_Over_ACSMOE_09_13',
#  'Not_HS_Grad_ACS_09_13',
#  'Not_HS_Grad_ACSMOE_09_13',
#  'College_ACS_09_13',
#  'College_ACSMOE_09_13',
#  'Pov_Univ_ACS_09_13',
#  'Pov_Univ_ACSMOE_09_13',
#  'Prs_Blw_Pov_Lev_ACS_09_13',
#  'Prs_Blw_Pov_Lev_ACSMOE_09_13',
#  'One_Health_Ins_ACS_09_13',
#  'One_Health_Ins_ACSMOE_09_13',
#  'Two_Plus_Health_Ins_ACS_09_13',
#  'Two_Plus_Health_Ins_ACSMOE_09_13',
#  'No_Health_Ins_ACS_09_13',
#  'No_Health_Ins_ACSMOE_09_13',
#  'Pop_1yr_Over_ACS_09_13',
#  'Pop_1yr_Over_ACSMOE_09_13',
#  'Diff_HU_1yr_Ago_ACS_09_13',
#  'Diff_HU_1yr_Ago_ACSMOE_09_13',
#  'ENG_VW_SPAN_ACS_09_13',
#  'ENG_VW_SPAN_ACSMOE_09_13',
#  'ENG_VW_INDO_EURO_ACS_09_13',
#  'ENG_VW_INDO_EURO_ACSMOE_09_13',
#  'ENG_VW_API_ACS_09_13',
#  'ENG_VW_API_ACSMOE_09_13',
#  'ENG_VW_OTHER_ACS_09_13',
#  'ENG_VW_OTHER_ACSMOE_09_13',
#  'ENG_VW_ACS_09_13',
#  'ENG_VW_ACSMOE_09_13',
#  'Rel_Family_HHDS_CEN_2010',
#  'Rel_Family_HHD_ACS_09_13',
#  'Rel_Family_HHD_ACSMOE_09_13',
#  'MrdCple_Fmly_HHD_CEN_2010',
#  'MrdCple_Fmly_HHD_ACS_09_13',
#  'MrdCple_Fmly_HHD_ACSMOE_09_13',
#  'Not_MrdCple_HHD_CEN_2010',
#  'Not_MrdCple_HHD_ACS_09_13',
#  'Not_MrdCple_HHD_ACSMOE_09_13',
#  'Female_No_HB_CEN_2010',
#  'Female_No_HB_ACS_09_13',
#  'Female_No_HB_ACSMOE_09_13',
#  'NonFamily_HHD_CEN_2010',
#  'NonFamily_HHD_ACS_09_13',
#  'NonFamily_HHD_ACSMOE_09_13',
#  'Sngl_Prns_HHD_CEN_2010',
#  'Sngl_Prns_HHD_ACS_09_13',
#  'Sngl_Prns_HHD_ACSMOE_09_13',
#  'HHD_PPL_Und_18_CEN_2010',
#  'HHD_PPL_Und_18_ACS_09_13',
#  'HHD_PPL_Und_18_ACSMOE_09_13',
#  'Tot_Prns_in_HHD_CEN_2010',
#  'Tot_Prns_in_HHD_ACS_09_13',
#  'Tot_Prns_in_HHD_ACSMOE_09_13',
#  'Rel_Child_Under_6_CEN_2010',
#  'Rel_Child_Under_6_ACS_09_13',
#  'Rel_Child_Under_6_ACSMOE_09_13',
#  'HHD_Moved_in_ACS_09_13',
#  'HHD_Moved_in_ACSMOE_09_13',
#  'PUB_ASST_INC_ACS_09_13',
#  'PUB_ASST_INC_ACSMOE_09_13',
#  'Med_HHD_Inc_BG_ACS_09_13',
#  'Med_HHD_Inc_BG_ACSMOE_09_13',
#  'Med_HHD_Inc_TR_ACS_09_13',
#  'Med_HHD_Inc_TR_ACSMOE_09_13',
#  'Aggregate_HH_INC_ACS_09_13',
#  'Aggregate_HH_INC_ACSMOE_09_13',
#  'Tot_Housing_Units_CEN_2010',
#  'Tot_Housing_Units_ACS_09_13',
#  'Tot_Housing_Units_ACSMOE_09_13',
#  'Tot_Occp_Units_CEN_2010',
#  'Tot_Occp_Units_ACS_09_13',
#  'Tot_Occp_Units_ACSMOE_09_13',
#  'Tot_Vacant_Units_CEN_2010',
#  'Tot_Vacant_Units_ACS_09_13',
#  'Tot_Vacant_Units_ACSMOE_09_13',
#  'Renter_Occp_HU_CEN_2010',
#  'Renter_Occp_HU_ACS_09_13',
#  'Renter_Occp_HU_ACSMOE_09_13',
#  'Owner_Occp_HU_CEN_2010',
#  'Owner_Occp_HU_ACS_09_13',
#  'Owner_Occp_HU_ACSMOE_09_13',
#  'Single_Unit_ACS_09_13',
#  'Single_Unit_ACSMOE_09_13',
#  'MLT_U2_9_STRC_ACS_09_13',
#  'MLT_U2_9_STRC_ACSMOE_09_13',
#  'MLT_U10p_ACS_09_13',
#  'MLT_U10p_ACSMOE_09_13',
#  'Mobile_Homes_ACS_09_13',
#  'Mobile_Homes_ACSMOE_09_13',
#  'Crowd_Occp_U_ACS_09_13',
#  'Crowd_Occp_U_ACSMOE_09_13',
#  'Occp_U_NO_PH_SRVC_ACS_09_13',
#  'Occp_U_NO_PH_SRVC_ACSMOE_09_13',
#  'No_Plumb_ACS_09_13',
#  'No_Plumb_ACSMOE_09_13',
#  'Recent_Built_HU_ACS_09_13',
#  'Recent_Built_HU_ACSMOE_09_13',
#  'Med_House_Value_BG_ACS_09_13',
#  'Med_House_Value_BG_ACSMOE_09_13',
#  'Med_house_value_TR_ACS_09_13',
#  'Med_house_value_TR_ACSMOE_09_13',
#  'Aggr_House_Value_ACS_09_13',
#  'Aggr_House_Value_ACSMOE_09_13',
#  'MailBack_Area_Count_CEN_2010',
#  'TEA_Mail_Out_Mail_Back_CEN_2010',
#  'TEA_Update_Leave_CEN_2010',
#  'Census_Mail_Returns_CEN_2010',
#  'Vacants_CEN_2010',
#  'Deletes_CEN_2010',
#  'Census_UAA_CEN_2010',
#  'Valid_Mailback_Count_CEN_2010',
#  'FRST_FRMS_CEN_2010',
#  'RPLCMNT_FRMS_CEN_2010',
#  'BILQ_Mailout_count_CEN_2010',
#  'BILQ_Frms_CEN_2010',
#  'Mail_Return_Rate_CEN_2010',
#  'Low_Response_Score',
#  'pct_URBANIZED_AREA_POP_CEN_2010',
#  'pct_URBAN_CLUSTER_POP_CEN_2010',
#  'pct_RURAL_POP_CEN_2010',
#  'pct_Males_CEN_2010',
#  'pct_Males_ACS_09_13',
#  'pct_Males_ACSMOE_09_13',
#  'pct_Females_CEN_2010',
#  'pct_Females_ACS_09_13',
#  'pct_Females_ACSMOE_09_13',
#  'pct_Pop_Under_5_CEN_2010',
#  'pct_Pop_Under_5_ACS_09_13',
#  'pct_Pop_Under_5_ACSMOE_09_13',
#  'pct_Pop_5_17_CEN_2010',
#  'pct_Pop_5_17_ACS_09_13',
#  'pct_Pop_5_17_ACSMOE_09_13',
#  'pct_Pop_18_24_CEN_2010',
#  'pct_Pop_18_24_ACS_09_13',
#  'pct_Pop_18_24_ACSMOE_09_13',
#  'pct_Pop_25_44_CEN_2010',
#  'pct_Pop_25_44_ACS_09_13',
#  'pct_Pop_25_44_ACSMOE_09_13',
#  'pct_Pop_45_64_CEN_2010',
#  'pct_Pop_45_64_ACS_09_13',
#  'pct_Pop_45_64_ACSMOE_09_13',
#  'pct_Pop_65plus_CEN_2010',
#  'pct_Pop_65plus_ACS_09_13',
#  'pct_Pop_65plus_ACSMOE_09_13',
#  'pct_Tot_GQ_CEN_2010',
#  'pct_Inst_GQ_CEN_2010',
#  'pct_Non_Inst_GQ_CEN_2010',
#  'pct_Hispanic_CEN_2010',
#  'pct_Hispanic_ACS_09_13',
#  'pct_Hispanic_ACSMOE_09_13',
#  'pct_NH_White_alone_CEN_2010',
#  'pct_NH_White_alone_ACS_09_13',
#  'pct_NH_White_alone_ACSMOE_09_13',
#  'pct_NH_Blk_alone_CEN_2010',
#  'pct_NH_Blk_alone_ACS_09_13',
#  'pct_NH_Blk_alone_ACSMOE_09_13',
#  'pct_NH_AIAN_alone_CEN_2010',
#  'pct_NH_AIAN_alone_ACS_09_13',
#  'pct_NH_AIAN_alone_ACSMOE_09_13',
#  'pct_NH_Asian_alone_CEN_2010',
#  'pct_NH_Asian_alone_ACS_09_13',
#  'pct_NH_Asian_alone_ACSMOE_09_13',
#  'pct_NH_NHOPI_alone_CEN_2010',
#  'pct_NH_NHOPI_alone_ACS_09_13',
#  'pct_NH_NHOPI_alone_ACSMOE_09_13',
#  'pct_NH_SOR_alone_CEN_2010',
#  'pct_NH_SOR_alone_ACS_09_13',
#  'pct_NH_SOR_alone_ACSMOE_09_13',
#  'pct_Pop_5yrs_Over_ACS_09_13',
#  'pct_Pop_5yrs_Over_ACSMOE_09_13',
#  'pct_Othr_Lang_ACS_09_13',
#  'pct_Othr_Lang_ACSMOE_09_13',
#  'pct_Pop_25yrs_Over_ACS_09_13',
#  'pct_Pop_25yrs_Over_ACSMOE_09_13',
#  'pct_Not_HS_Grad_ACS_09_13',
#  'pct_Not_HS_Grad_ACSMOE_09_13',
#  'pct_College_ACS_09_13',
#  'pct_College_ACSMOE_09_13',
#  'pct_Prs_Blw_Pov_Lev_ACS_09_13',
#  'pct_Prs_Blw_Pov_Lev_ACSMOE_09_13',
#  'pct_One_Health_Ins_ACS_09_13',
#  'pct_One_Health_Ins_ACSMOE_09_13',
#  'pct_TwoPHealth_Ins_ACS_09_13',
#  'pct_TwoPHealthIns_ACSMOE_09_13',
#  'pct_No_Health_Ins_ACS_09_13',
#  'pct_No_Health_Ins_ACSMOE_09_13',
#  'pct_Pov_Univ_ACS_09_13',
#  'pct_Pov_Univ_ACSMOE_09_13',
#  'pct_Pop_1yr_Over_ACS_09_13',
#  'pct_Pop_1yr_Over_ACSMOE_09_13',
#  'pct_Diff_HU_1yr_Ago_ACS_09_13',
#  'pct_Diff_HU_1yr_Ago_ACSMOE_09_13',
#  'pct_ENG_VW_SPAN_ACS_09_13',
#  'pct_ENG_VW_SPAN_ACSMOE_09_13',
#  'pct_ENG_VW_INDOEURO_ACS_09_13',
#  'pct_ENG_VW_INDOEURO_ACSMOE_09_13',
#  'pct_ENG_VW_API_ACS_09_13',
#  'pct_ENG_VW_API_ACSMOE_09_13',
#  'pct_ENG_VW_OTHER_ACS_09_13',
#  'pct_ENG_VW_OTHER_ACSMOE_09_13',
#  'pct_ENG_VW_ACS_09_13',
#  'pct_ENG_VW_ACSMOE_09_13',
#  'pct_Rel_Family_HHDS_CEN_2010',
#  'pct_Rel_Family_HHD_ACS_09_13',
#  'pct_Rel_Family_HHD_ACSMOE_09_13',
#  'pct_MrdCple_HHD_CEN_2010',
#  'pct_MrdCple_HHD_ACS_09_13',
#  'pct_MrdCple_HHD_ACSMOE_09_13',
#  'pct_Not_MrdCple_HHD_CEN_2010',
#  'pct_Not_MrdCple_HHD_ACS_09_13',
#  'pct_Not_MrdCple_HHD_ACSMOE_09_13',
#  'pct_Female_No_HB_CEN_2010',
#  'pct_Female_No_HB_ACS_09_13',
#  'pct_Female_No_HB_ACSMOE_09_13',
#  'pct_NonFamily_HHD_CEN_2010',
#  'pct_NonFamily_HHD_ACS_09_13',
#  'pct_NonFamily_HHD_ACSMOE_09_13',
#  'pct_Sngl_Prns_HHD_CEN_2010',
#  'pct_Sngl_Prns_HHD_ACS_09_13',
#  'pct_Sngl_Prns_HHD_ACSMOE_09_13',
#  'pct_HHD_PPL_Und_18_CEN_2010',
#  'pct_HHD_PPL_Und_18_ACS_09_13',
#  'pct_HHD_PPL_Und_18_ACSMOE_09_13',
#  'avg_Tot_Prns_in_HHD_CEN_2010',
#  'avg_Tot_Prns_in_HHD_ACS_09_13',
#  'avg_Tot_Prns_in_HHD_ACSMOE_09_13',
#  'pct_Rel_Under_6_CEN_2010',
#  'pct_Rel_Under_6_ACS_09_13',
#  'pct_Rel_Under_6_ACSMOE_09_13',
#  'pct_HHD_Moved_in_ACS_09_13',
#  'pct_HHD_Moved_in_ACSMOE_09_13',
#  'pct_PUB_ASST_INC_ACS_09_13',
#  'pct_PUB_ASST_INC_ACSMOE_09_13',
#  'avg_Agg_HH_INC_ACS_09_13',
#  'avg_Agg_HH_INC_ACSMOE_09_13',
#  'pct_Tot_Occp_Units_CEN_2010',
#  'pct_Tot_Occp_Units_ACS_09_13',
#  'pct_Tot_Occp_Units_ACSMOE_09_13',
#  'pct_Vacant_Units_CEN_2010',
#  'pct_Vacant_Units_ACS_09_13',
#  'pct_Vacant_Units_ACSMOE_09_13',
#  'pct_Renter_Occp_HU_CEN_2010',
#  'pct_Renter_Occp_HU_ACS_09_13',
#  'pct_Renter_Occp_HU_ACSMOE_09_13',
#  'pct_Owner_Occp_HU_CEN_2010',
#  'pct_Owner_Occp_HU_ACS_09_13',
#  'pct_Owner_Occp_HU_ACSMOE_09_13',
#  'pct_Single_Unit_ACS_09_13',
#  'pct_Single_Unit_ACSMOE_09_13',
#  'pct_MLT_U2_9_STRC_ACS_09_13',
#  'pct_MLT_U2_9_STRC_ACSMOE_09_13',
#  'pct_MLT_U10p_ACS_09_13',
#  'pct_MLT_U10p_ACSMOE_09_13',
#  'pct_Mobile_Homes_ACS_09_13',
#  'pct_Mobile_Homes_ACSMOE_09_13',
#  'pct_Crowd_Occp_U_ACS_09_13',
#  'pct_Crowd_Occp_U_ACSMOE_09_13',
#  'pct_NO_PH_SRVC_ACS_09_13',
#  'pct_NO_PH_SRVC_ACSMOE_09_13',
#  'pct_No_Plumb_ACS_09_13',
#  'pct_No_Plumb_ACSMOE_09_13',
#  'pct_Recent_Built_HU_ACS_09_13',
#  'pct_Recent_Built_HU_ACSMOE_09_13',
#  'avg_Agg_House_Value_ACS_09_13',
#  'avg_Agg_House_Value_ACSMOE_09_13',
#  'pct_TEA_MailOutMailBack_CEN_2010',
#  'pct_TEA_Update_Leave_CEN_2010',
#  'pct_Census_Mail_Returns_CEN_2010',
#  'pct_Vacant_CEN_2010',
#  'pct_Deletes_CEN_2010',
#  'pct_Census_UAA_CEN_2010',
#  'pct_Mailback_Count_CEN_2010',
#  'pct_FRST_FRMS_CEN_2010',
#  'pct_RPLCMNT_FRMS_CEN_2010',
#  'pct_BILQ_Mailout_count_CEN_2010']

# %% [markdown]
# ### Create a list of column types
# All the JSON data came in as either integers, strings, or floats.

# %%
superfund_column_types = list(superfund_sites_df.dtypes)
superfund_column_types
# Out:
# [dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64')]

# %% [markdown]
# ### Take a peek at the head

# %%
superfund_sites_df.head()
# Out:
#          FIPS_Full                                            address  \
# 0   11210113001044              STATE HWY 235, CHILDERSBURG, AL 35044
# 1   11170301021051           570 HIGHWAY 231 NORTH, VINCENT, AL 35178
# 2   11010060001057          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108
# 3   60375021002013  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...
# 4  420659503005008                   ROUTE 950, FALLS CREEK, PA 15840
#
#            city  date_added federal_facility_ind  \
# 0  Childersburg  07/22/1987                  Yes
# 1       Vincent  09/18/2012                   No
# 2    Montgomery  08/30/1990                   No
# 3      Whittier  01/19/1999                   No
# 4   Falls Creek  09/14/2005                   No
#
#                                 federal_register_url geocode_source  \
# 0     https://semspub.epa.gov/src/document/11/189629   full_address
# 1  http://www.gpo.gov/fdsys/pkg/FR-2012-09-18/pdf...   full_address
# 2     https://semspub.epa.gov/src/document/11/189637   full_address
# 3  http://www.gpo.gov/fdsys/pkg/FR-1999-01-19/pdf...   full_address
# 4  http://www.gpo.gov/fdsys/pkg/FR-2005-09-14/pdf...   full_address
#
#     latitude   longitude   site_epa_id  ... pct_TEA_MailOutMailBack_CEN_2010  \
# 0  33.286432  -86.358807  AL6210020008  ...                           100.00
# 1  33.399231  -86.404985  ALD004022448  ...                           100.00
# 2  32.367036  -86.372935  ALD007454085  ...                           100.00
# 3  33.969447 -118.043443  CAD042245001  ...                           100.00
# 4  41.145061  -78.804365  PAD001222025  ...                            46.31
#
#   pct_TEA_Update_Leave_CEN_2010 pct_Census_Mail_Returns_CEN_2010  \
# 0                          0.00                            74.03
# 1                          0.00                            55.28
# 2                          0.00                            27.33
# 3                          0.00                            72.02
# 4                         53.69                            73.60
#
#    pct_Vacant_CEN_2010 pct_Deletes_CEN_2010  pct_Census_UAA_CEN_2010  \
# 0                 3.58                  0.0                    10.90
# 1                 2.44                  0.0                    31.06
# 2                 2.84                  0.0                    54.19
# 3                 1.46                  0.0                     3.58
# 4                 4.03                  4.7                     3.80
#
#    pct_Mailback_Count_CEN_2010 pct_FRST_FRMS_CEN_2010  \
# 0                        85.52                  67.16
# 1                        66.50                  48.62
# 2                        42.97                  23.06
# 3                        94.96                  72.02
# 4                        87.47                  71.59
#
#    pct_RPLCMNT_FRMS_CEN_2010 pct_BILQ_Mailout_count_CEN_2010
# 0                       6.87                            0.00
# 1                       6.67                            0.00
# 2                       4.27                            0.00
# 3                       0.00                           97.88
# 4                       2.01                            0.00
#
# [5 rows x 359 columns]

# %% [markdown]
# ### Export the dataframe as a csv for manual inspection

# %%
superfund_sites_df.to_csv(import_inspection_file, index = False)

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Define the desired columns
# The columns listed below were selected for potential visualization.

# %%
# Create a filtered dataframe from specific columns
desired_columns = ["address",
                "city",
                "latitude",
                "longitude",
                "site_score",
                "text",
                "State_name",
                "County_name",
                "Tract",
                "Block_Group",
                "Tot_Population_CEN_2010",
                "Hispanic_CEN_2010",
                "NH_Blk_alone_CEN_2010",
                "NH_AIAN_alone_CEN_2010",
                "NH_Asian_alone_CEN_2010",
                "NH_NHOPI_alone_CEN_2010",
                "NH_SOR_alone_CEN_2010",
                "College_ACS_09_13",
                "No_Health_Ins_ACS_09_13",
                "Med_HHD_Inc_BG_ACS_09_13",
                "Aggregate_HH_INC_ACS_09_13",
                "Tot_Vacant_Units_CEN_2010",
                "Renter_Occp_HU_CEN_2010",
                "Owner_Occp_HU_CEN_2010",
                "No_Plumb_ACS_09_13",
                "Med_House_Value_BG_ACS_09_13",
                "pct_Hispanic_CEN_2010",
                "pct_NH_Blk_alone_CEN_2010",
                "pct_NH_AIAN_alone_CEN_2010",
                "pct_NH_Asian_alone_CEN_2010",
                "pct_NH_NHOPI_alone_CEN_2010",
                "pct_NH_SOR_alone_CEN_2010",
                "pct_Not_HS_Grad_ACS_09_13",
                "pct_No_Health_Ins_ACS_09_13",
                "pct_Vacant_Units_CEN_2010",
                "pct_Renter_Occp_HU_CEN_2010",
                "pct_Owner_Occp_HU_CEN_2010",
                "pct_No_Plumb_ACS_09_13"]

# %% [markdown]
# ### Create the filtered dataframe

# %%
# pull in the desired columns
superfund_sites_cleaned = superfund_sites_df[desired_columns].copy()

# convert the column names to lowercase to avoid problems with postgreSQL.
superfund_sites_cleaned.columns= superfund_sites_cleaned.columns.str.lower()

# make sure the census block groups and tracts come through as integers
superfund_sites_cleaned.tract = superfund_sites_cleaned.tract.fillna(0.0).astype(int)
superfund_sites_cleaned.block_group = superfund_sites_cleaned.block_group.fillna(0.0).astype(int)

# convert currency strings to floats
superfund_sites_cleaned[['med_hhd_inc_bg_acs_09_13']] = (superfund_sites_cleaned['med_hhd_inc_bg_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

superfund_sites_cleaned[['aggregate_hh_inc_acs_09_13']] = (superfund_sites_cleaned['aggregate_hh_inc_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

superfund_sites_cleaned[['med_house_value_bg_acs_09_13']] = (superfund_sites_cleaned['med_house_value_bg_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

# rename the 'text' column to avoid potential confusion
superfund_sites_cleaned.rename(columns={"text": "site_text"}, inplace = True)

# fill in nulls with zeros
superfund_sites_cleaned.fillna(0, inplace = True)

# check the head
superfund_sites_cleaned.head()
# Out:
#                                              address          city   latitude  \
# 0              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg  33.286432
# 1           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent  33.399231
# 2          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery  32.367036
# 3  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier  33.969447
# 4                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek  41.145061
#
#     longitude  site_score                                          site_text  \
# 0  -86.358807       36.83  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1  -86.404985       30.20  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...
# 2  -86.372935       44.46  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 3 -118.043443       30.94  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 4  -78.804365       30.22  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...
#
#      state_name         county_name   tract  block_group  ...  \
# 0       Alabama    Talladega County   11300            1  ...
# 1       Alabama       Shelby County   30102            1  ...
# 2       Alabama   Montgomery County    6000            1  ...
# 3    California  Los Angeles County  502100            2  ...
# 4  Pennsylvania    Jefferson County  950300            5  ...
#
#    pct_nh_aian_alone_cen_2010  pct_nh_asian_alone_cen_2010  \
# 0                        0.07                         0.21
# 1                        0.29                         0.00
# 2                        0.00                         0.00
# 3                        0.42                         1.69
# 4                        0.20                         0.20
#
#    pct_nh_nhopi_alone_cen_2010  pct_nh_sor_alone_cen_2010  \
# 0                         0.00                       0.14
# 1                         0.00                       0.00
# 2                         0.00                       0.11
# 3                         0.04                       0.08
# 4                         0.00                       0.00
#
#    pct_not_hs_grad_acs_09_13  pct_no_health_ins_acs_09_13  \
# 0                      17.62                         5.32
# 1                      30.23                        14.50
# 2                      50.87                        33.92
# 3                      31.43                        22.99
# 4                       7.70                        10.70
#
#    pct_vacant_units_cen_2010  pct_renter_occp_hu_cen_2010  \
# 0                      12.89                        19.02
# 1                       9.02                        16.00
# 2                      24.11                        33.11
# 3                       3.60                        61.83
# 4                       7.53                        27.91
#
#    pct_owner_occp_hu_cen_2010  pct_no_plumb_acs_09_13
# 0                       80.98                    0.00
# 1                       84.00                    7.02
# 2                       66.89                    0.00
# 3                       38.17                    3.52
# 4                       72.09                    2.06
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Create a list of column types
# A list of column types is useful for checking against the database table. (We need to verify that there are no surprises, like currency stored as a string.)

# %%
superfund_cleaned_column_types = list(superfund_sites_cleaned.dtypes)
dtype_reference = list(zip(superfund_sites_cleaned.columns.values, superfund_cleaned_column_types))
dtype_reference
# Out:
# [('address', dtype('O')),
#  ('city', dtype('O')),
#  ('latitude', dtype('float64')),
#  ('longitude', dtype('float64')),
#  ('site_score', dtype('float64')),
#  ('site_text', dtype('O')),
#  ('state_name', dtype('O')),
#  ('county_name', dtype('O')),
#  ('tract', dtype('int32')),
#  ('block_group', dtype('int32')),
#  ('tot_population_cen_2010', dtype('float64')),
#  ('hispanic_cen_2010', dtype('float64')),
#  ('nh_blk_alone_cen_2010', dtype('float64')),
#  ('nh_aian_alone_cen_2010', dtype('float64')),
#  ('nh_asian_alone_cen_2010', dtype('float64')),
#  ('nh_nhopi_alone_cen_2010', dtype('float64')),
#  ('nh_sor_alone_cen_2010', dtype('float64')),
#  ('college_acs_09_13', dtype('float64')),
#  ('no_health_ins_acs_09_13', dtype('float64')),
#  ('med_hhd_inc_bg_acs_09_13', dtype('float64')),
#  ('aggregate_hh_inc_acs_09_13', dtype('float64')),
#  ('tot_vacant_units_cen_2010', dtype('float64')),
#  ('renter_occp_hu_cen_2010', dtype('float64')),
#  ('owner_occp_hu_cen_2010', dtype('float64')),
#  ('no_plumb_acs_09_13', dtype('float64')),
#  ('med_house_value_bg_acs_09_13', dtype('float64')),
#  ('pct_hispanic_cen_2010', dtype('float64')),
#  ('pct_nh_blk_alone_cen_2010', dtype('float64')),
#  ('pct_nh_aian_alone_cen_2010', dtype('float64')),
#  ('pct_nh_asian_alone_cen_2010', dtype('float64')),
#  ('pct_nh_nhopi_alone_cen_2010', dtype('float64')),
#  ('pct_nh_sor_alone_cen_2010', dtype('float64')),
#  ('pct_not_hs_grad_acs_09_13', dtype('float64')),
#  ('pct_no_health_ins_acs_09_13', dtype('float64')),
#  ('pct_vacant_units_cen_2010', dtype('float64')),
#  ('pct_renter_occp_hu_cen_2010', dtype('float64')),
#  ('pct_owner_occp_hu_cen_2010', dtype('float64')),
#  ('pct_no_plumb_acs_09_13', dtype('float64'))]

# %% [markdown]
# ### Export the cleaned dataframe to csv for inspection

# %%
superfund_sites_cleaned.to_csv(cleaning_inspection_file, index = False)

# %% [markdown]
# ## Load the Cleaned Data into Pre-Analysis Database
# The cleaned data is loaded into a database for storage. Dat pulled from here will be used for analysis.

# %% [markdown]
# ### Connect to the database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/project_2_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['superfund_data_table', 'superfund_analysis_table']

# %% [markdown]
# ### Load the cleaned dataframe into the database

# %%
superfund_sites_cleaned.to_sql(name='superfund_data_table', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm the Load

# %%
pd.read_sql_query('select * from superfund_data_table', con=engine).head()
# Out:
#    id                                            address          city  \
# 0   1              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg
# 1   2           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent
# 2   3          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery
# 3   4  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier
# 4   5                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek
#
#     latitude   longitude  site_score  \
# 0  33.286432  -86.358807       36.83
# 1  33.399231  -86.404985       30.20
# 2  32.367036  -86.372935       44.46
# 3  33.969447 -118.043443       30.94
# 4  41.145061  -78.804365       30.22
#
#                                            site_text    state_name  \
# 0  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 1  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...       Alabama
# 2  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 3  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...    California
# 4  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...  Pennsylvania
#
#           county_name   tract  ...  pct_nh_aian_alone_cen_2010  \
# 0    Talladega County   11300  ...                        0.07
# 1       Shelby County   30102  ...                        0.29
# 2   Montgomery County    6000  ...                        0.00
# 3  Los Angeles County  502100  ...                        0.42
# 4    Jefferson County  950300  ...                        0.20
#
#    pct_nh_asian_alone_cen_2010  pct_nh_nhopi_alone_cen_2010  \
# 0                         0.21                         0.00
# 1                         0.00                         0.00
# 2                         0.00                         0.00
# 3                         1.69                         0.04
# 4                         0.20                         0.00
#
#    pct_nh_sor_alone_cen_2010  pct_not_hs_grad_acs_09_13  \
# 0                       0.14                      17.62
# 1                       0.00                      30.23
# 2                       0.11                      50.87
# 3                       0.08                      31.43
# 4                       0.00                       7.70
#
#    pct_no_health_ins_acs_09_13  pct_vacant_units_cen_2010  \
# 0                         5.32                      12.89
# 1                        14.50                       9.02
# 2                        33.92                      24.11
# 3                        22.99                       3.60
# 4                        10.70                       7.53
#
#    pct_renter_occp_hu_cen_2010  pct_owner_occp_hu_cen_2010  \
# 0                        19.02                       80.98
# 1                        16.00                       84.00
# 2                        33.11                       66.89
# 3                        61.83                       38.17
# 4                        27.91                       72.09
#
#    pct_no_plumb_acs_09_13
# 0                    0.00
# 1                    7.02
# 2                    0.00
# 3                    3.52
# 4                    2.06
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Analysis

# %%
# Grab the data from the database
superfund_sites_for_analysis = pd.read_sql_query('select * from superfund_data_table', con=engine)

# %%
superfund_sites_analyzed = superfund_sites_for_analysis.copy()

# %%
superfund_sites_analyzed["pct_poc"] = (
    superfund_sites_analyzed.pct_hispanic_cen_2010 +\
    superfund_sites_analyzed.pct_nh_blk_alone_cen_2010 +\
    superfund_sites_analyzed.pct_nh_aian_alone_cen_2010 +\
    superfund_sites_analyzed.pct_nh_asian_alone_cen_2010 +\
    superfund_sites_analyzed.pct_nh_nhopi_alone_cen_2010 +\
    superfund_sites_analyzed.pct_nh_sor_alone_cen_2010)

# %%
superfund_sites_analyzed.head()
# Out:
#    id                                            address          city  \
# 0   1              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg
# 1   2           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent
# 2   3          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery
# 3   4  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier
# 4   5                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek
#
#     latitude   longitude  site_score  \
# 0  33.286432  -86.358807       36.83
# 1  33.399231  -86.404985       30.20
# 2  32.367036  -86.372935       44.46
# 3  33.969447 -118.043443       30.94
# 4  41.145061  -78.804365       30.22
#
#                                            site_text    state_name  \
# 0  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 1  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...       Alabama
# 2  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 3  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...    California
# 4  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...  Pennsylvania
#
#           county_name   tract  ...  pct_nh_asian_alone_cen_2010  \
# 0    Talladega County   11300  ...                         0.21
# 1       Shelby County   30102  ...                         0.00
# 2   Montgomery County    6000  ...                         0.00
# 3  Los Angeles County  502100  ...                         1.69
# 4    Jefferson County  950300  ...                         0.20
#
#    pct_nh_nhopi_alone_cen_2010  pct_nh_sor_alone_cen_2010  \
# 0                         0.00                       0.14
# 1                         0.00                       0.00
# 2                         0.00                       0.11
# 3                         0.04                       0.08
# 4                         0.00                       0.00
#
#    pct_not_hs_grad_acs_09_13  pct_no_health_ins_acs_09_13  \
# 0                      17.62                         5.32
# 1                      30.23                        14.50
# 2                      50.87                        33.92
# 3                      31.43                        22.99
# 4                       7.70                        10.70
#
#    pct_vacant_units_cen_2010  pct_renter_occp_hu_cen_2010  \
# 0                      12.89                        19.02
# 1                       9.02                        16.00
# 2                      24.11                        33.11
# 3                       3.60                        61.83
# 4                       7.53                        27.91
#
#    pct_owner_occp_hu_cen_2010  pct_no_plumb_acs_09_13  pct_poc
# 0                       80.98                    0.00    20.29
# 1                       84.00                    7.02    30.49
# 2                       66.89                    0.00    81.57
# 3                       38.17                    3.52    85.29
# 4                       72.09                    2.06     1.31
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Load the Analyzed Data into Post-Analysis Database
# The cleaned data is loaded into a database for storage. Dat pulled from here will be used for analysis.

# %%
rds_connection_string = "postgres:postgres@localhost:5432/project_2_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['superfund_data_table', 'superfund_analysis_table']

# %%
superfund_sites_analyzed.to_sql(name='superfund_analysis_table', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm the Load

# %%
pd.read_sql_query('select * from superfund_analysis_table', con=engine).head()
# Out:
#    id                                            address          city  \
# 0   1              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg
# 1   2           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent
# 2   3          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery
# 3   4  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier
# 4   5                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek
#
#     latitude   longitude  site_score  \
# 0  33.286432  -86.358807       36.83
# 1  33.399231  -86.404985       30.20
# 2  32.367036  -86.372935       44.46
# 3  33.969447 -118.043443       30.94
# 4  41.145061  -78.804365       30.22
#
#                                            site_text    state_name  \
# 0  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 1  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...       Alabama
# 2  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 3  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...    California
# 4  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...  Pennsylvania
#
#           county_name   tract  ...  pct_nh_asian_alone_cen_2010  \
# 0    Talladega County   11300  ...                         0.21
# 1       Shelby County   30102  ...                         0.00
# 2   Montgomery County    6000  ...                         0.00
# 3  Los Angeles County  502100  ...                         1.69
# 4    Jefferson County  950300  ...                         0.20
#
#    pct_nh_nhopi_alone_cen_2010  pct_nh_sor_alone_cen_2010  \
# 0                         0.00                       0.14
# 1                         0.00                       0.00
# 2                         0.00                       0.11
# 3                         0.04                       0.08
# 4                         0.00                       0.00
#
#    pct_not_hs_grad_acs_09_13  pct_no_health_ins_acs_09_13  \
# 0                      17.62                         5.32
# 1                      30.23                        14.50
# 2                      50.87                        33.92
# 3                      31.43                        22.99
# 4                       7.70                        10.70
#
#    pct_vacant_units_cen_2010  pct_renter_occp_hu_cen_2010  \
# 0                      12.89                        19.02
# 1                       9.02                        16.00
# 2                      24.11                        33.11
# 3                       3.60                        61.83
# 4                       7.53                        27.91
#
#    pct_owner_occp_hu_cen_2010  pct_no_plumb_acs_09_13  pct_poc
# 0                       80.98                    0.00    20.29
# 1                       84.00                    7.02    30.49
# 2                       66.89                    0.00    81.57
# 3                       38.17                    3.52    85.29
# 4                       72.09                    2.06     1.31
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Export the Data

# %% [markdown]
# ### Pull the Data

# %%
rds_connection_string = "postgres:postgres@localhost:5432/project_2_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
superfund_sites_for_viz = pd.read_sql_query('select * from superfund_analysis_table', con=engine)

# %%
#### Drop the site_text column
superfund_sites_for_viz = superfund_sites_for_viz.drop(['site_text'], axis=1)

# %% [markdown]
# ### Export the cleaned dataframe to csv

# %%
superfund_sites_for_viz.to_csv(viz_inspection_file, index = False)

# %% [markdown]
# ### Export in GEOJSON format
# (Much thanks to Geoff Boeing for his post "Exporting Python Data to GeoJSON":
# https://geoffboeing.com/2015/10/exporting-python-data-geojson/)

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['tract','address', 'site_score', 'med_hhd_inc_bg_acs_09_13', 'pct_no_health_ins_acs_09_13', 'pct_poc']
geojson = df_to_geojson(superfund_sites_for_viz, cols)

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'tract': 11300,
#     'address': 'STATE HWY 235, CHILDERSBURG, AL 35044',
#     'site_score': 36.83,
#     'med_hhd_inc_bg_acs_09_13': 36534.0,
#     'pct_no_health_ins_acs_09_13': 5.32,
#     'pct_poc': 20.29},
#    'geometry': {'type': 'Point', 'coordinates': [-86.3588071, 33.286432]}},
#   {'type': 'Feature',
#    'properties': {'tract': 30102,
#     'address': '570 HIGHWAY 231 NORTH, VINCENT, AL 35178',
#     'site_score': 30.2,
#     'med_hhd_inc_bg_acs_09_13': 50219.0,
#     'pct_no_health_ins_acs_09_13': 14.5,
#     'pct_poc': 30.49},
#    'geometry': {'type': 'Point', 'coordinates': [-86.4049851, 33.3992313]}},
#   {'type': 'Feature',
#    'properties': {'tract': 6000,
#     'address': '3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108',
#     'site_score': 44.46,
#     'med_hhd_inc_bg_acs_09_13': 30930.0,
#     'pct_no_health_ins_acs_09_13': 33.92,
#     'pct_poc': 81.57000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-86.3729352, 32.3670357]}},
#   {'type': 'Feature',
#    'properties': {'tract': 502100,
#     'address': '12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIER, CA 90602',
#     'site_score': 30.94,
#     'med_hhd_inc_bg_acs_09_13': 39925.0,
#     'pct_no_health_ins_acs_09_13': 22.99,
#     'pct_poc': 85.29},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0434426, 33.9694468]}},
#   {'type': 'Feature',
#    'properties': {'tract': 950300,
#     'address': 'ROUTE 950, FALLS CREEK, PA 15840',
#     'site_score': 30.22,
#     'med_hhd_inc_bg_acs_09_13': 40573.0,
#     'pct_no_health_ins_acs_09_13': 10.7,
#     'pct_poc': 1.31},
#    'geometry': {'type': 'Point', 'coordinates': [-78.8043651, 41.1450611]}},
#   {'type': 'Feature',
#    'properties': {'tract': 31203,
#     'address': 'RD #1, UNION TOWNSHIP, PA 17331',
#     'site_score': 33.76,
#     'med_hhd_inc_bg_acs_09_13': 73895.0,
#     'pct_no_health_ins_acs_09_13': 7.88,
#     'pct_poc': 3.69},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0449327, 39.7542614]}},
#   {'type': 'Feature',
#    'properties': {'tract': 301000,
#     'address': 'COLD STREAM &amp; HARES HILL ROADS, EAST PIKELAND TOWNSHIP, PA 19442',
#     'site_score': 29.44,
#     'med_hhd_inc_bg_acs_09_13': 108289.0,
#     'pct_no_health_ins_acs_09_13': 5.75,
#     'pct_poc': 4.17},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5778849, 40.1336266]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11200,
#     'address': 'N FRANKLIN ST, FRANKLIN COUNTY, PA 17201',
#     'site_score': 37.51,
#     'med_hhd_inc_bg_acs_09_13': 35150.0,
#     'pct_no_health_ins_acs_09_13': 21.27,
#     'pct_poc': 26.449999999999996},
#    'geometry': {'type': 'Point', 'coordinates': [-77.6674469, 39.9449996]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11200,
#     'address': 'N FRANKLIN ST EXT, CHAMBERSBURG, PA 17201',
#     'site_score': 34.21,
#     'med_hhd_inc_bg_acs_09_13': 42143.0,
#     'pct_no_health_ins_acs_09_13': 11.48,
#     'pct_poc': 24.709999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-77.669615, 39.947575]}},
#   {'type': 'Feature',
#    'properties': {'tract': 401100,
#     'address': 'RTE 28 &amp; SPRING HILL ROAD, HARRISON TOWNSHIP, PA 15065',
#     'site_score': 51.62,
#     'med_hhd_inc_bg_acs_09_13': 42813.0,
#     'pct_no_health_ins_acs_09_13': 20.8,
#     'pct_poc': 2.3100000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-79.71669, 40.63664]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10202,
#     'address': 'RD #1 PIEPER ROAD, GIRARD TOWNSHIP, PA 16417',
#     'site_score': 38.89,
#     'med_hhd_inc_bg_acs_09_13': 68617.0,
#     'pct_no_health_ins_acs_09_13': 9.76,
#     'pct_poc': 1.67},
#    'geometry': {'type': 'Point', 'coordinates': [-80.3101684, 41.9743464]}},
#   {'type': 'Feature',
#    'properties': {'tract': 402600,
#     'address': 'DARBY CRK BETWEEN , DARBY TWP, PA 19023',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 39330.0,
#     'pct_no_health_ins_acs_09_13': 7.03,
#     'pct_poc': 52.440000000000005},
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.26832279999999, 39.9200613]}},
#   {'type': 'Feature',
#    'properties': {'tract': 302101,
#     'address': '258 N PHOENIXVILLE PK, MALVERN, PA 19355',
#     'site_score': 46.69,
#     'med_hhd_inc_bg_acs_09_13': 129904.0,
#     'pct_no_health_ins_acs_09_13': 7.88,
#     'pct_poc': 24.240000000000002},
#    'geometry': {'type': 'Point', 'coordinates': [-75.570648, 40.060908]}},
#   {'type': 'Feature',
#    'properties': {'tract': 32300,
#     'address': 'COTTMAN &amp; DELAWARE AVE, PHILADELPHIA, PA 19135',
#     'site_score': 33.23,
#     'med_hhd_inc_bg_acs_09_13': 45085.0,
#     'pct_no_health_ins_acs_09_13': 7.97,
#     'pct_poc': 45.080000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0552739, 40.0203813]}},
#   {'type': 'Feature',
#    'properties': {'tract': 482800,
#     'address': '900 N POTRERO GRANDE DR, MONTEREY PARK, CA 91754',
#     'site_score': 57.22,
#     'med_hhd_inc_bg_acs_09_13': 74886.0,
#     'pct_no_health_ins_acs_09_13': 13.98,
#     'pct_poc': 85.49},
#    'geometry': {'type': 'Point', 'coordinates': [-118.1133754, 34.0328348]}},
#   {'type': 'Feature',
#    'properties': {'tract': 406500,
#     'address': 'CORNER OF WEST 2ND ST. AND PRICE STREET, TRAINER, PA 19061',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 36406.0,
#     'pct_no_health_ins_acs_09_13': 15.81,
#     'pct_poc': 31.849999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3983639, 39.8266539]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10500,
#     'address': '3081 W 17TH ST, ERIE, PA 16505',
#     'site_score': 49.31,
#     'med_hhd_inc_bg_acs_09_13': 40263.0,
#     'pct_no_health_ins_acs_09_13': 12.21,
#     'pct_poc': 5.57},
#    'geometry': {'type': 'Point', 'coordinates': [-80.1485551, 42.0938162]}},
#   {'type': 'Feature',
#    'properties': {'tract': 208704,
#     'address': 'ARMAND HAMMER BLVD, LOWER POTTSGROVE TOWNSHIP, PA 19464',
#     'site_score': 45.91,
#     'med_hhd_inc_bg_acs_09_13': 81853.0,
#     'pct_no_health_ins_acs_09_13': 8.66,
#     'pct_poc': 13.98},
#    'geometry': {'type': 'Point', 'coordinates': [-75.6157547, 40.2325708]}},
#   {'type': 'Feature',
#    'properties': {'tract': 461000,
#     'address': 'GRAND AVE, NEVILLE ISLAND, PA 15225',
#     'site_score': 42.24,
#     'med_hhd_inc_bg_acs_09_13': 36111.0,
#     'pct_no_health_ins_acs_09_13': 10.77,
#     'pct_poc': 10.329999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-80.1225373, 40.5094964]}},
#   {'type': 'Feature',
#    'properties': {'tract': 901,
#     'address': 'HELMICK ST, NORFOLK, VA 23511',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 45318.0,
#     'pct_no_health_ins_acs_09_13': 0.5700000000000001,
#     'pct_poc': 44.739999999999995},
#    'geometry': {'type': 'Point', 'coordinates': [-76.3113022, 36.9264535]}},
#   {'type': 'Feature',
#    'properties': {'tract': 50800,
#     'address': '4150 A. OLD BERWICK ROAD, BLOOMSBURG, PA 17815',
#     'site_score': 70.71,
#     'med_hhd_inc_bg_acs_09_13': 39141.0,
#     'pct_no_health_ins_acs_09_13': 7.2,
#     'pct_poc': 2.54},
#    'geometry': {'type': 'Point', 'coordinates': [-76.376249, 41.01576]}},
#   {'type': 'Feature',
#    'properties': {'tract': 23301,
#     'address': '4400 MT. PISGAH ROAD, LOWER WINDSOR TWP, PA 17406-8240',
#     'site_score': 33.93,
#     'med_hhd_inc_bg_acs_09_13': 86083.0,
#     'pct_no_health_ins_acs_09_13': 5.59,
#     'pct_poc': 14.010000000000002},
#    'geometry': {'type': 'Point', 'coordinates': [-76.5905848, 39.9550927]}},
#   {'type': 'Feature',
#    'properties': {'tract': 50400,
#     'address': 'STATE ROUTE 54 AND I-80, VALLEY TOWNSHIP, PA 17821',
#     'site_score': 46.44,
#     'med_hhd_inc_bg_acs_09_13': 71563.0,
#     'pct_no_health_ins_acs_09_13': 3.15,
#     'pct_poc': 3.4699999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6481401, 40.9969874]}},
#   {'type': 'Feature',
#    'properties': {'tract': 101609,
#     'address': 'ST &amp; JACKSONVILLE ROAD, WARMINSTER TOWNSHIP, PA 18974',
#     'site_score': 57.93,
#     'med_hhd_inc_bg_acs_09_13': 61544.0,
#     'pct_no_health_ins_acs_09_13': 16.42,
#     'pct_poc': 9.610000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-75.099807, 40.2067884]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11700,
#     'address': 'OFF STATE HIGHWAY 641, MECHANICSBURG, PA 17055',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 52539.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 3.44},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0426223, 40.202896]}},
#   {'type': 'Feature',
#    'properties': {'tract': 207201,
#     'address': '162 N MAIN ST, SOUDERTON, PA 18964',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 51250.0,
#     'pct_no_health_ins_acs_09_13': 5.5,
#     'pct_poc': 23.270000000000003},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3247731, 40.3114597]}},
#   {'type': 'Feature',
#    'properties': {'tract': 206801,
#     'address': 'TROOPER RD, WORCESTER, PA 19490',
#     'site_score': 28.9,
#     'med_hhd_inc_bg_acs_09_13': 127778.0,
#     'pct_no_health_ins_acs_09_13': 5.51,
#     'pct_poc': 20.72},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3509981, 40.1794834]}},
#   {'type': 'Feature',
#    'properties': {'tract': 200901,
#     'address': '1 SPRING AVE, HATFIELD, PA 19440',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 53182.0,
#     'pct_no_health_ins_acs_09_13': 18.38,
#     'pct_poc': 48.19},
#    'geometry': {'type': 'Point', 'coordinates': [-75.281794, 40.2504561]}},
#   {'type': 'Feature',
#    'properties': {'tract': 200603,
#     'address': 'MAPLE DR, MONTGOMERY TOWNSHIP, PA 18915',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 108640.0,
#     'pct_no_health_ins_acs_09_13': 3.52,
#     'pct_poc': 16.04},
#    'geometry': {'type': 'Point', 'coordinates': [-75.2503589, 40.2649446]}},
#   {'type': 'Feature',
#    'properties': {'tract': 302,
#     'address': '67 E TELEGRAPH RD, FILLMORE, CA 93015',
#     'site_score': 46.01,
#     'med_hhd_inc_bg_acs_09_13': 31396.0,
#     'pct_no_health_ins_acs_09_13': 12.22,
#     'pct_poc': 58.42},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9020044, 34.3991147]}},
#   {'type': 'Feature',
#    'properties': {'tract': 200908,
#     'address': 'W 3RD ST, LANSDALE, PA 19446',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 55813.0,
#     'pct_no_health_ins_acs_09_13': 7.53,
#     'pct_poc': 20.37},
#    'geometry': {'type': 'Point', 'coordinates': [-75.2888959, 40.2473305]}},
#   {'type': 'Feature',
#    'properties': {'tract': 201003,
#     'address': 'WISSAHICKON AVE, NORTH WALES, PA 19454',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 75250.0,
#     'pct_no_health_ins_acs_09_13': 2.76,
#     'pct_poc': 33.38},
#    'geometry': {'type': 'Point', 'coordinates': [-75.2813183, 40.2209906]}},
#   {'type': 'Feature',
#    'properties': {'tract': 6002,
#     'address': 'PARKLAND TERRACE RD &amp; LAPP RD, SOUTH WHITEHALL TOWNSHIP, PA 18104',
#     'site_score': 42.31,
#     'med_hhd_inc_bg_acs_09_13': 91583.0,
#     'pct_no_health_ins_acs_09_13': 2.71,
#     'pct_poc': 12.679999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-75.565955, 40.6108861]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21712,
#     'address': 'RD# 1 SOUTH RD, SEVEN VALLEYS, PA 17360',
#     'site_score': 33.93,
#     'med_hhd_inc_bg_acs_09_13': 53000.0,
#     'pct_no_health_ins_acs_09_13': 21.72,
#     'pct_poc': 3.29},
#    'geometry': {'type': 'Point', 'coordinates': [-76.7685823, 39.8556561]}},
#   {'type': 'Feature',
#    'properties': {'tract': 305101,
#     'address': 'OLD WILMINGTON ROAD, SADSBURYVILLE, PA 19320',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 63500.0,
#     'pct_no_health_ins_acs_09_13': 16.59,
#     'pct_poc': 5.399999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-75.9019032, 39.9962584]}},
#   {'type': 'Feature',
#    'properties': {'tract': 32900,
#     'address': '0.5 MILES E OF TOWN, GROVE CITY, PA 16127',
#     'site_score': 54.6,
#     'med_hhd_inc_bg_acs_09_13': 31944.0,
#     'pct_no_health_ins_acs_09_13': 8.49,
#     'pct_poc': 5.41},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0865136, 41.1609283]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20900,
#     'address': '211 FRANKLIN ST, PALMERTON, PA 18071',
#     'site_score': 42.93,
#     'med_hhd_inc_bg_acs_09_13': 45278.0,
#     'pct_no_health_ins_acs_09_13': 20.42,
#     'pct_poc': 4.45},
#    'geometry': {'type': 'Point', 'coordinates': [-75.612931, 40.80216]}},
#   {'type': 'Feature',
#    'properties': {'tract': 300103,
#     'address': 'RR SERVICE SHOP, PAOLI, PA 19301',
#     'site_score': 32.18,
#     'med_hhd_inc_bg_acs_09_13': 83200.0,
#     'pct_no_health_ins_acs_09_13': 18.73,
#     'pct_poc': 20.389999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-75.4876445, 40.0419021]}},
#   {'type': 'Feature',
#    'properties': {'tract': 533703,
#     'address': '5050 SLAUSON BOULEVARD, MAYWOOD, CA 90270',
#     'site_score': 45.23,
#     'med_hhd_inc_bg_acs_09_13': 35150.0,
#     'pct_no_health_ins_acs_09_13': 31.43,
#     'pct_poc': 99.18},
#    'geometry': {'type': 'Point', 'coordinates': [-118.172289, 33.9855919]}},
#   {'type': 'Feature',
#    'properties': {'tract': 13800,
#     'address': '246 GRAND STREET, HAMBURG, PA 19526',
#     'site_score': 37.86,
#     'med_hhd_inc_bg_acs_09_13': 55147.0,
#     'pct_no_health_ins_acs_09_13': 10.51,
#     'pct_poc': 6.61},
#    'geometry': {'type': 'Point', 'coordinates': [-75.983981, 40.5501502]}},
#   {'type': 'Feature',
#    'properties': {'tract': 200402,
#     'address': '220 JACKSONVILLE RD, HATBORO, PA 19040',
#     'site_score': 53.42,
#     'med_hhd_inc_bg_acs_09_13': 98295.0,
#     'pct_no_health_ins_acs_09_13': 2.8200000000000003,
#     'pct_poc': 7.46},
#    'geometry': {'type': 'Point', 'coordinates': [-75.098739, 40.179676]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11902,
#     'address': 'RTE 724 &amp; WELLS RD, E COVENTRY TWP, PA 19457',
#     'site_score': 32.06,
#     'med_hhd_inc_bg_acs_09_13': 75000.0,
#     'pct_no_health_ins_acs_09_13': 2.9,
#     'pct_poc': 2.54},
#    'geometry': {'type': 'Point', 'coordinates': [-75.7706225, 40.2565388]}},
#   {'type': 'Feature',
#    'properties': {'tract': 103300,
#     'address': 'SOUTHEAST SIDE OF ROUTE 611, NOCKAMIXON TOWNSHIP, PA 18972',
#     'site_score': 31.31,
#     'med_hhd_inc_bg_acs_09_13': 81827.0,
#     'pct_no_health_ins_acs_09_13': 2.12,
#     'pct_poc': 3.48},
#    'geometry': {'type': 'Point', 'coordinates': [-75.270088, 40.4941369]}},
#   {'type': 'Feature',
#    'properties': {'tract': 6600,
#     'address': '6TH &amp; MINOR STREETS, EMMAUS BOROUGH, PA 18049',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 75139.0,
#     'pct_no_health_ins_acs_09_13': 5.16,
#     'pct_poc': 3.37},
#    'geometry': {'type': 'Point', 'coordinates': [-75.4968502, 40.5395421]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10500,
#     'address': 'RYELAND ROAD, HEIDELBERG TWP, PA 19567',
#     'site_score': 60.3,
#     'med_hhd_inc_bg_acs_09_13': 71333.0,
#     'pct_no_health_ins_acs_09_13': 10.82,
#     'pct_poc': 6.09},
#    'geometry': {'type': 'Point', 'coordinates': [-76.1722481, 40.3541031]}},
#   {'type': 'Feature',
#    'properties': {'tract': 110700,
#     'address': 'GRANT ST, SAEGERTOWN, PA 16433',
#     'site_score': 33.62,
#     'med_hhd_inc_bg_acs_09_13': 35781.0,
#     'pct_no_health_ins_acs_09_13': 9.91,
#     'pct_poc': 2.87},
#    'geometry': {'type': 'Point', 'coordinates': [-80.1451436, 41.7204022]}},
#   {'type': 'Feature',
#    'properties': {'tract': 207001,
#     'address': '610 QUARRY ROAD, LOWER SALFORD TOWNSHIP, PA 19438',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 102969.0,
#     'pct_no_health_ins_acs_09_13': 0.72,
#     'pct_poc': 14.030000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3824169, 40.2519393]}},
#   {'type': 'Feature',
#    'properties': {'tract': 31100,
#     'address': '300 OHIO STREET, HERMITAGE, PA 16159',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 18030.0,
#     'pct_no_health_ins_acs_09_13': 7.03,
#     'pct_poc': 21.619999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-80.5075428, 41.1988294]}},
#   {'type': 'Feature',
#    'properties': {'tract': 1500,
#     'address': '3265 S MAPLE AVE, MALAGA, CA 93725',
#     'site_score': 43.27,
#     'med_hhd_inc_bg_acs_09_13': 16719.0,
#     'pct_no_health_ins_acs_09_13': 40.08,
#     'pct_poc': 62.33999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-119.7464118, 36.6873923]}},
#   {'type': 'Feature',
#    'properties': {'tract': 30600,
#     'address': 'RD #6 ALONG RTE 394, STRABAN TOWNSHIP, PA 17325',
#     'site_score': 46.13,
#     'med_hhd_inc_bg_acs_09_13': 53125.0,
#     'pct_no_health_ins_acs_09_13': 9.43,
#     'pct_poc': 13.68},
#    'geometry': {'type': 'Point', 'coordinates': [-77.1735312, 39.8716058]}},
#   {'type': 'Feature',
#    'properties': {'tract': 205905,
#     'address': '103 QUEENS DR, KING OF PRUSSIA, PA 19406',
#     'site_score': 33.89,
#     'med_hhd_inc_bg_acs_09_13': 65083.0,
#     'pct_no_health_ins_acs_09_13': 8.22,
#     'pct_poc': 25.740000000000002},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3548676, 40.0840787]}},
#   {'type': 'Feature',
#    'properties': {'tract': 311200,
#     'address': 'STRASBURG ROAD, NEWLIN TOWNSHIP, PA 19320',
#     'site_score': 30.71,
#     'med_hhd_inc_bg_acs_09_13': 104205.0,
#     'pct_no_health_ins_acs_09_13': 1.99,
#     'pct_poc': 4.43},
#    'geometry': {'type': 'Point', 'coordinates': [-75.7732455, 39.94791]}},
#   {'type': 'Feature',
#    'properties': {'tract': 300308,
#     'address': '11 HAP ARNOLD BOULEVARD, TOBYHANNA, PA 184665086',
#     'site_score': 37.93,
#     'med_hhd_inc_bg_acs_09_13': 42232.0,
#     'pct_no_health_ins_acs_09_13': 4.44,
#     'pct_poc': 24.01},
#    'geometry': {'type': 'Point', 'coordinates': [-75.4204872, 41.1870857]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20300,
#     'address': 'RTE 54, NESQUEHONING, PA 18240',
#     'site_score': 46.58,
#     'med_hhd_inc_bg_acs_09_13': 52500.0,
#     'pct_no_health_ins_acs_09_13': 2.5700000000000003,
#     'pct_poc': 1.7599999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-75.8811461, 40.8471308]}},
#   {'type': 'Feature',
#    'properties': {'tract': 205809,
#     'address': '310 BROWNLIE RD., UPPER MERION TWP, PA 19406',
#     'site_score': 63.1,
#     'med_hhd_inc_bg_acs_09_13': 121094.0,
#     'pct_no_health_ins_acs_09_13': 4.8,
#     'pct_poc': 20.270000000000003},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3654604, 40.1105681]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11200,
#     'address': 'FRONT STREET, COLUMBIA, PA 17512',
#     'site_score': 50.78,
#     'med_hhd_inc_bg_acs_09_13': 34020.0,
#     'pct_no_health_ins_acs_09_13': 14.97,
#     'pct_poc': 21.37},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4955774, 40.0250352]}},
#   {'type': 'Feature',
#    'properties': {'tract': 217900,
#     'address': 'DEER RUN ROAD, WEST HAZLETON, PA 18201',
#     'site_score': 43.16,
#     'med_hhd_inc_bg_acs_09_13': 31346.0,
#     'pct_no_health_ins_acs_09_13': 12.25,
#     'pct_poc': 19.959999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-76.0111304, 40.9713439]}},
#   {'type': 'Feature',
#    'properties': {'tract': 5205,
#     'address': '8350 FRUITRIDGE RD, SACRAMENTO, CA 95813',
#     'site_score': 44.46,
#     'med_hhd_inc_bg_acs_09_13': 21000.0,
#     'pct_no_health_ins_acs_09_13': 11.41,
#     'pct_poc': 33.54},
#    'geometry': {'type': 'Point', 'coordinates': [-121.395831, 38.525168]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20701,
#     'address': 'PERRY HILL RD, COVENTRY, RI 02816',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 80000.0,
#     'pct_no_health_ins_acs_09_13': 5.16,
#     'pct_poc': 2.81},
#    'geometry': {'type': 'Point', 'coordinates': [-71.7158024, 41.6800381]}},
#   {'type': 'Feature',
#    'properties': {'tract': 304900,
#     'address': 'WALSH ROAD, HONEYBROOK TOWNSHIP, PA 19344',
#     'site_score': 33.64,
#     'med_hhd_inc_bg_acs_09_13': 68750.0,
#     'pct_no_health_ins_acs_09_13': 39.1,
#     'pct_poc': 3.37},
#    'geometry': {'type': 'Point', 'coordinates': [-75.9074097, 40.1161455]}},
#   {'type': 'Feature',
#    'properties': {'tract': 106500,
#     'address': 'E PUMPING STA RD, RICHLAND TOWNSHIP, PA 18951',
#     'site_score': 70.71,
#     'med_hhd_inc_bg_acs_09_13': 63833.0,
#     'pct_no_health_ins_acs_09_13': 10.2,
#     'pct_poc': 1.19},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3371847, 40.4639311]}},
#   {'type': 'Feature',
#    'properties': {'tract': 509108,
#     'address': '350 ELLIS ST, MOUNTAIN VIEW, CA 94043',
#     'site_score': 29.76,
#     'med_hhd_inc_bg_acs_09_13': 97024.0,
#     'pct_no_health_ins_acs_09_13': 7.29,
#     'pct_poc': 48.88999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0540132, 37.3970434]}},
#   {'type': 'Feature',
#    'properties': {'tract': 33200,
#     'address': '469 SHARPSVILLE AVE, SHARON, PA 16146',
#     'site_score': 41.33,
#     'med_hhd_inc_bg_acs_09_13': 12396.0,
#     'pct_no_health_ins_acs_09_13': 11.45,
#     'pct_poc': 28.139999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-80.5052932, 41.2426341]}},
#   {'type': 'Feature',
#    'properties': {'tract': 31401,
#     'address': '1200BIGLERSVILLE RD, RTE 34 N, GETTYSBURG, PA 17325',
#     'site_score': 36.37,
#     'med_hhd_inc_bg_acs_09_13': 68182.0,
#     'pct_no_health_ins_acs_09_13': 5.38,
#     'pct_poc': 12.87},
#    'geometry': {'type': 'Point', 'coordinates': [-77.2311351, 39.8401913]}},
#   {'type': 'Feature',
#    'properties': {'tract': 2900,
#     'address': '19 N RAILROAD ST, JACKSON TOWNSHIP, PA 17067',
#     'site_score': 46.25,
#     'med_hhd_inc_bg_acs_09_13': 46307.0,
#     'pct_no_health_ins_acs_09_13': 8.82,
#     'pct_poc': 4.4799999999999995},
#    'geometry': {'type': 'Point', 'coordinates': [-76.30388, 40.376286]}},
#   {'type': 'Feature',
#    'properties': {'tract': 305102,
#     'address': 'TELEGRAPH ROAD, WEST CALN TOWNSHIP, PA 19376',
#     'site_score': 36.64,
#     'med_hhd_inc_bg_acs_09_13': 89816.0,
#     'pct_no_health_ins_acs_09_13': 8.03,
#     'pct_poc': 3.91},
#    'geometry': {'type': 'Point', 'coordinates': [-75.8797647, 40.0501857]}},
#   {'type': 'Feature',
#    'properties': {'tract': 103700,
#     'address': 'RT 611 &amp; COUNTY LINE ROAD, HORSHAM, PA 19040',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 71779.0,
#     'pct_no_health_ins_acs_09_13': 13.11,
#     'pct_poc': 2.8200000000000003},
#    'geometry': {'type': 'Point', 'coordinates': [-75.1833187, 40.5459554]}},
#   {'type': 'Feature',
#    'properties': {'tract': 950500,
#     'address': 'Postal Address is unavailable for the Site, VIEQUES, PR 00765',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 19350.0,
#     'pct_no_health_ins_acs_09_13': 6.04,
#     'pct_poc': 96.17999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-65.4400985, 18.1262854]}},
#   {'type': 'Feature',
#    'properties': {'tract': 830400,
#     'address': 'CROSS STR. CALLE BARBOSA &amp; CALLE DEDIEGO, CABO ROJO, PR 00623',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 6699.0,
#     'pct_no_health_ins_acs_09_13': 6.47,
#     'pct_poc': 99.01},
#    'geometry': {'type': 'Point', 'coordinates': [-67.1469964, 18.0875347]}},
#   {'type': 'Feature',
#    'properties': {'tract': 809200,
#     'address': 'ROAD 171 (SOUTH OF THE VILLAGE OF CIDRA, CIDRA, PR 08750',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 103000.0,
#     'pct_no_health_ins_acs_09_13': 0.32,
#     'pct_poc': 2.0},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0358876, 40.1318193]}},
#   {'type': 'Feature',
#    'properties': {'tract': 520500,
#     'address': '[OFF OF] CARRETERA 811 KM 3.0, COROZAL, PR 00783',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 19464.0,
#     'pct_no_health_ins_acs_09_13': 10.73,
#     'pct_poc': 99.67},
#    'geometry': {'type': 'Point', 'coordinates': [-66.2799655, 18.3001802]}},
#   {'type': 'Feature',
#    'properties': {'tract': 540500,
#     'address': 'PR-694 Km 4.5, DORADO, PR 00646',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 31179.0,
#     'pct_no_health_ins_acs_09_13': 9.66,
#     'pct_poc': 99.28},
#    'geometry': {'type': 'Point', 'coordinates': [-66.2825495, 18.4295077]}},
#   {'type': 'Feature',
#    'properties': {'tract': 402,
#     'address': '5300 CLAUS RD, RIVERBANK, CA 95367',
#     'site_score': 63.94,
#     'med_hhd_inc_bg_acs_09_13': 43935.0,
#     'pct_no_health_ins_acs_09_13': 14.44,
#     'pct_poc': 32.300000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-120.921728, 37.714874]}},
#   {'type': 'Feature',
#    'properties': {'tract': 51305,
#     'address': 'ROSE HILL RD, SOUTH KINGSTOWN, RI 02880',
#     'site_score': 38.11,
#     'med_hhd_inc_bg_acs_09_13': 62386.0,
#     'pct_no_health_ins_acs_09_13': 4.79,
#     'pct_poc': 8.26},
#    'geometry': {'type': 'Point', 'coordinates': [-71.4966569, 41.4737865]}},
#   {'type': 'Feature',
#    'properties': {'tract': 12801,
#     'address': 'MAIN ST, NORTH SMITHFIELD, RI 02824',
#     'site_score': 34.07,
#     'med_hhd_inc_bg_acs_09_13': 67400.0,
#     'pct_no_health_ins_acs_09_13': 7.39,
#     'pct_poc': 4.449999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-71.58229, 42.0034754]}},
#   {'type': 'Feature',
#    'properties': {'tract': 0,
#     'address': 'RTE 3, JOBOS, PR 00654',
#     'site_score': 35.34,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'tract': 31021,
#     'address': 'CARRETERA 785 KM 4.9, CAGUAS, PR 00725',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 21200.0,
#     'pct_no_health_ins_acs_09_13': 14.75,
#     'pct_poc': 99.48},
#    'geometry': {'type': 'Point', 'coordinates': [-66.1775525, 18.4142542]}},
#   {'type': 'Feature',
#    'properties': {'tract': 500302,
#     'address': 'BO CEIBA NORTE, ROAD 189, JUNCOS, PR 00666',
#     'site_score': 32.57,
#     'med_hhd_inc_bg_acs_09_13': 14339.0,
#     'pct_no_health_ins_acs_09_13': 5.26,
#     'pct_poc': 99.32000000000001},
#    'geometry': {'type': 'Point',
#     'coordinates': [-65.89744519999999, 18.2192134]}},
#   {'type': 'Feature',
#    'properties': {'tract': 951600,
#     'address': 'STATE ROAD #3, KM 110.2, MAUNABO, PR 00707',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 15750.0,
#     'pct_no_health_ins_acs_09_13': 5.23,
#     'pct_poc': 98.91999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-65.8968722, 18.0077296]}},
#   {'type': 'Feature',
#    'properties': {'tract': 957500,
#     'address': 'RD 111 KM 1.8, VIVI ABAJO WARD, UTUADO, PR 00641',
#     'site_score': 34.69,
#     'med_hhd_inc_bg_acs_09_13': 6687.0,
#     'pct_no_health_ins_acs_09_13': 9.83,
#     'pct_poc': 99.66},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7005065, 18.266146]}},
#   {'type': 'Feature',
#    'properties': {'tract': 301100,
#     'address': 'ROAD # 2 KM 59.7, ARECIBO, PR 00612',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 21424.0,
#     'pct_no_health_ins_acs_09_13': 6.34,
#     'pct_poc': 99.88},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7464487, 18.4528424]}},
#   {'type': 'Feature',
#    'properties': {'tract': 0,
#     'address': 'ROAD 670 KM 3.7 PALO ALTO, MANATI, PR 00701',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'tract': 840700,
#     'address': 'STATE ROAD #122 (ALSO KNOWN AS ROAD 119), San German, PR 00683',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 21741.0,
#     'pct_no_health_ins_acs_09_13': 2.55,
#     'pct_poc': 99.27000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0411096, 18.0807082]}},
#   {'type': 'Feature',
#    'properties': {'tract': 0,
#     'address': 'STATE ROAD #2 KM. 19.7 (ACUNA STREET), CANDELERIA WARD, PR 00759',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'tract': 300400,
#     'address': 'ROAD 2 KM 72.2 BO. CAMBALACHE, ARECIBO, PR 00612',
#     'site_score': 56.66,
#     'med_hhd_inc_bg_acs_09_13': 14250.0,
#     'pct_no_health_ins_acs_09_13': 7.54,
#     'pct_poc': 99.23},
#    'geometry': {'type': 'Point', 'coordinates': [-66.704033, 18.4676828]}},
#   {'type': 'Feature',
#    'properties': {'tract': 2704,
#     'address': '3196 NORTH LOCUST AVENUE, RIALTO, CA 92377',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 95000.0,
#     'pct_no_health_ins_acs_09_13': 10.09,
#     'pct_poc': 83.15000000000002},
#    'geometry': {'type': 'Point', 'coordinates': [-117.4098098, 34.1576911]}},
#   {'type': 'Feature',
#    'properties': {'tract': 40102,
#     'address': 'DEFENSE HIGHWAY (BURMA RD.), NEWPORT, RI 02871',
#     'site_score': 32.25,
#     'med_hhd_inc_bg_acs_09_13': 74911.0,
#     'pct_no_health_ins_acs_09_13': 3.86,
#     'pct_poc': 3.4800000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-71.2517835, 41.5905625]}},
#   {'type': 'Feature',
#    'properties': {'tract': 61203,
#     'address': '5080 CURETON FERRY RD, ROCK HILL, SC 29704',
#     'site_score': 47.1,
#     'med_hhd_inc_bg_acs_09_13': 39722.0,
#     'pct_no_health_ins_acs_09_13': 12.09,
#     'pct_poc': 19.71},
#    'geometry': {'type': 'Point', 'coordinates': [-80.9097127, 34.8415786]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20201,
#     'address': 'US 321 1 MILE S OF I-26, CAYCE, SC 29033',
#     'site_score': 37.93,
#     'med_hhd_inc_bg_acs_09_13': 18427.0,
#     'pct_no_health_ins_acs_09_13': 21.06,
#     'pct_poc': 19.299999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-81.0485598, 33.9874133]}},
#   {'type': 'Feature',
#    'properties': {'tract': 5400,
#     'address': '1800 PITTSBURGH AVENUE, NORTH CHARLESTON, SC 29405',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 6263.0,
#     'pct_no_health_ins_acs_09_13': 6.5600000000000005,
#     'pct_poc': 97.69000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-79.950247, 32.839643]}},
#   {'type': 'Feature',
#    'properties': {'tract': 590100,
#     'address': 'RTE 2, BARCELONETA, PR 00617',
#     'site_score': 41.92,
#     'med_hhd_inc_bg_acs_09_13': 10461.0,
#     'pct_no_health_ins_acs_09_13': 9.31,
#     'pct_poc': 99.47},
#    'geometry': {'type': 'Point', 'coordinates': [-66.5554901, 18.4831288]}},
#   {'type': 'Feature',
#    'properties': {'tract': 51400,
#     'address': 'PLAINS ROAD, SOUTH KINGSTOWN, RI 02881',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 35424.0,
#     'pct_no_health_ins_acs_09_13': 6.11,
#     'pct_poc': 17.25},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5420358, 41.4894497]}},
#   {'type': 'Feature',
#    'properties': {'tract': 550400,
#     'address': 'HIGHWAY 2, VEGA ALTA, PR 00762',
#     'site_score': 42.24,
#     'med_hhd_inc_bg_acs_09_13': 10667.0,
#     'pct_no_health_ins_acs_09_13': 3.73,
#     'pct_poc': 99.77999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-66.330311, 18.4144497]}},
#   {'type': 'Feature',
#    'properties': {'tract': 0,
#     'address': 'ROAD 674, KM 2, RIO ABAJO WARD, PR 00763',
#     'site_score': 50.37,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'tract': 12200,
#     'address': '65 SHUN PIKE, JOHNSTON, RI 029194512',
#     'site_score': 46.71,
#     'med_hhd_inc_bg_acs_09_13': 38789.0,
#     'pct_no_health_ins_acs_09_13': 13.64,
#     'pct_poc': 6.72},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5231325, 41.8046652]}},
#   {'type': 'Feature',
#    'properties': {'tract': 12104,
#     'address': '2072 AND 2074 SMITH STREET (ROUTE 44), NORTH PROVIDENCE, RI 02911',
#     'site_score': 70.71,
#     'med_hhd_inc_bg_acs_09_13': 26731.0,
#     'pct_no_health_ins_acs_09_13': 10.75,
#     'pct_poc': 15.62},
#    'geometry': {'type': 'Point', 'coordinates': [-71.486333, 41.856311]}},
#   {'type': 'Feature',
#    'properties': {'tract': 13002,
#     'address': 'TARKILN RD, SMITHFIELD, RI 02828',
#     'site_score': 47.25,
#     'med_hhd_inc_bg_acs_09_13': 62014.0,
#     'pct_no_health_ins_acs_09_13': 11.67,
#     'pct_poc': 1.55},
#    'geometry': {'type': 'Point', 'coordinates': [-71.6093782, 41.9540545]}},
#   {'type': 'Feature',
#    'properties': {'tract': 50103,
#     'address': 'OFF SANFORD RD., NORTH KINGSTOWN, RI 02818',
#     'site_score': 34.52,
#     'med_hhd_inc_bg_acs_09_13': 51544.0,
#     'pct_no_health_ins_acs_09_13': 4.0,
#     'pct_poc': 20.900000000000002},
#    'geometry': {'type': 'Point', 'coordinates': [-71.4209594, 41.6170235]}},
#   {'type': 'Feature',
#    'properties': {'tract': 12803,
#     'address': 'OXFORD RD, NORTH SMITHFIELD, RI 02876',
#     'site_score': 49.58,
#     'med_hhd_inc_bg_acs_09_13': 90833.0,
#     'pct_no_health_ins_acs_09_13': 5.2,
#     'pct_poc': 3.2499999999999996},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5828552, 41.973272]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11301,
#     'address': 'MARTIN ST, LINCOLN/CUMBERLAND, RI 02864',
#     'site_score': 40.1,
#     'med_hhd_inc_bg_acs_09_13': 55000.0,
#     'pct_no_health_ins_acs_09_13': 5.24,
#     'pct_poc': 20.819999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-71.4267688, 41.9279206]}},
#   {'type': 'Feature',
#    'properties': {'tract': 13002,
#     'address': 'DOUGLAS PIKE, BURRILLVILLE, RI 02895',
#     'site_score': 51.35,
#     'med_hhd_inc_bg_acs_09_13': 62014.0,
#     'pct_no_health_ins_acs_09_13': 11.67,
#     'pct_poc': 1.55},
#    'geometry': {'type': 'Point', 'coordinates': [-71.6550962, 42.0080273]}},
#   {'type': 'Feature',
#    'properties': {'tract': 23202,
#     'address': '340 ROBINSON ROAD, GREER, SC 29651',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 37125.0,
#     'pct_no_health_ins_acs_09_13': 21.81,
#     'pct_poc': 47.7},
#    'geometry': {'type': 'Point', 'coordinates': [-82.170567, 34.932742]}},
#   {'type': 'Feature',
#    'properties': {'tract': 920200,
#     'address': 'NORTHERN SIDE OF SECONDARY HWY S-33-30, MCCORMICK, SC 29835',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 21029.0,
#     'pct_no_health_ins_acs_09_13': 8.18,
#     'pct_poc': 70.04999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-82.2934585, 33.9134577]}},
#   {'type': 'Feature',
#    'properties': {'tract': 3101,
#     'address': '206 GEORGIA AVE, FOUNTAIN INN, SC 29644',
#     'site_score': 32.44,
#     'med_hhd_inc_bg_acs_09_13': 27778.0,
#     'pct_no_health_ins_acs_09_13': 21.52,
#     'pct_poc': 32.910000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-82.2122179, 34.697076]}},
#   {'type': 'Feature',
#    'properties': {'tract': 950200,
#     'address': '1/2 MI. N.OFINTERSECTION OF SR 265&amp;CR110, JEFFERSON, SC 29718',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 36792.0,
#     'pct_no_health_ins_acs_09_13': 20.51,
#     'pct_poc': 34.75},
#    'geometry': {'type': 'Point', 'coordinates': [-80.3889566, 34.6501547]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20800,
#     'address': 'S. OF SC HWY 9 ON CO. RD 841, FORT LAWN, SC 29714',
#     'site_score': 32.04,
#     'med_hhd_inc_bg_acs_09_13': 31458.0,
#     'pct_no_health_ins_acs_09_13': 19.24,
#     'pct_poc': 35.63},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8947978, 34.7020889]}},
#   {'type': 'Feature',
#    'properties': {'tract': 125200,
#     'address': 'NORTH HOLLYWOOD WELLFIELD AREA, NORTH HOLLYWOOD, CA 91601',
#     'site_score': 42.24,
#     'med_hhd_inc_bg_acs_09_13': 53816.0,
#     'pct_no_health_ins_acs_09_13': 32.13,
#     'pct_poc': 32.660000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-118.3790801, 34.1671344]}},
#   {'type': 'Feature',
#    'properties': {'tract': 23302,
#     'address': '117 HIGHLAND AVE, GREER, SC 29651',
#     'site_score': 31.45,
#     'med_hhd_inc_bg_acs_09_13': 22785.0,
#     'pct_no_health_ins_acs_09_13': 29.61,
#     'pct_poc': 78.02},
#    'geometry': {'type': 'Point', 'coordinates': [-82.2203643, 34.9370727]}},
#   {'type': 'Feature',
#    'properties': {'tract': 970400,
#     'address': 'HWY 321 S, FAIRFAX, SC 29829',
#     'site_score': 33.89,
#     'med_hhd_inc_bg_acs_09_13': 19427.0,
#     'pct_no_health_ins_acs_09_13': 30.47,
#     'pct_poc': 76.68},
#    'geometry': {'type': 'Point', 'coordinates': [-81.2313888, 32.973622]}},
#   {'type': 'Feature',
#    'properties': {'tract': 600,
#     'address': 'PO BOX 908, BEAUFORT, SC 29902',
#     'site_score': 57.9,
#     'med_hhd_inc_bg_acs_09_13': 45733.0,
#     'pct_no_health_ins_acs_09_13': 23.24,
#     'pct_poc': 34.00000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-80.6698286, 32.4315813]}},
#   {'type': 'Feature',
#    'properties': {'tract': 5500,
#     'address': 'CHARLESTON HEIGHTS, CHARLESTON, SC 29405',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 15147.0,
#     'pct_no_health_ins_acs_09_13': 21.02,
#     'pct_poc': 79.75999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-79.9707721, 32.8572503]}},
#   {'type': 'Feature',
#    'properties': {'tract': 970502,
#     'address': 'SC HIGHWAY 18, GAFFNEY, SC 29340',
#     'site_score': 31.58,
#     'med_hhd_inc_bg_acs_09_13': 13661.0,
#     'pct_no_health_ins_acs_09_13': 30.19,
#     'pct_poc': 67.04},
#    'geometry': {'type': 'Point', 'coordinates': [-81.646669, 35.0754905]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20605,
#     'address': 'DIXIANNA RD, DIXIANA, SC 29033',
#     'site_score': 38.43,
#     'med_hhd_inc_bg_acs_09_13': 51190.0,
#     'pct_no_health_ins_acs_09_13': 11.19,
#     'pct_poc': 18.29},
#    'geometry': {'type': 'Point', 'coordinates': [-81.064892, 33.9223913]}},
#   {'type': 'Feature',
#    'properties': {'tract': 3009,
#     'address': 'HWY 145, SIMPSONVILLE, SC 29681',
#     'site_score': 32.94,
#     'med_hhd_inc_bg_acs_09_13': 71136.0,
#     'pct_no_health_ins_acs_09_13': 5.02,
#     'pct_poc': 12.51},
#    'geometry': {'type': 'Point', 'coordinates': [-82.2089477, 34.7742827]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11100,
#     'address': 'USAMICOM DRSMI KL, LIMESTONE/MORGAN, AL 35898',
#     'site_score': 61.42,
#     'med_hhd_inc_bg_acs_09_13': 59286.0,
#     'pct_no_health_ins_acs_09_13': 5.72,
#     'pct_poc': 33.400000000000006},
#    'geometry': {'type': 'Point', 'coordinates': [-86.65, 34.63]}},
#   {'type': 'Feature',
#    'properties': {'tract': 302002,
#     'address': 'CRYSTAL SPRINGS WELLFIELD AREA, GLENDALE, CA 91209',
#     'site_score': 42.24,
#     'med_hhd_inc_bg_acs_09_13': 40000.0,
#     'pct_no_health_ins_acs_09_13': 26.76,
#     'pct_poc': 39.809999999999995},
#    'geometry': {'type': 'Point', 'coordinates': [-118.2519928, 34.1466245]}},
#   {'type': 'Feature',
#    'properties': {'tract': 1000,
#     'address': 'MARINE CORPS RECRUIT DEPOT, PARRIS ISLAND, SC 29902',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 49861.0,
#     'pct_no_health_ins_acs_09_13': 0.79,
#     'pct_poc': 29.7},
#    'geometry': {'type': 'Point', 'coordinates': [-80.6891655, 32.3513924]}},
#   {'type': 'Feature',
#    'properties': {'tract': 60804,
#     'address': 'NORTH CHERRY RD, ROCK HILL, SC 29730',
#     'site_score': 40.29,
#     'med_hhd_inc_bg_acs_09_13': 40208.0,
#     'pct_no_health_ins_acs_09_13': 25.01,
#     'pct_poc': 36.43},
#    'geometry': {'type': 'Point', 'coordinates': [-81.0043857, 34.9612357]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10402,
#     'address': 'SANGAMO RD, PICKENS, SC 29671',
#     'site_score': 37.63,
#     'med_hhd_inc_bg_acs_09_13': 31146.0,
#     'pct_no_health_ins_acs_09_13': 12.5,
#     'pct_poc': 8.47},
#    'geometry': {'type': 'Point', 'coordinates': [-82.7188261, 34.8955109]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21400,
#     'address': 'BETWEEN SC 125 &amp; US 278, AIKEN, SC 29802',
#     'site_score': 47.7,
#     'med_hhd_inc_bg_acs_09_13': 18944.0,
#     'pct_no_health_ins_acs_09_13': 12.98,
#     'pct_poc': 62.379999999999995},
#    'geometry': {'type': 'Point', 'coordinates': [-81.721042, 33.5660738]}},
#   {'type': 'Feature',
#    'properties': {'tract': 2800,
#     'address': '321 BLUFF RD S, COLUMBIA, SC 29209',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 23563.0,
#     'pct_no_health_ins_acs_09_13': 28.46,
#     'pct_poc': 27.43},
#    'geometry': {'type': 'Point', 'coordinates': [-81.0280634, 33.9790142]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21620,
#     'address': '719 PIPER STREET, COLLIERVILLE, TN 38017',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 50673.0,
#     'pct_no_health_ins_acs_09_13': 6.23,
#     'pct_poc': 54.54999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-89.6864738, 35.0446642]}},
#   {'type': 'Feature',
#    'properties': {'tract': 3500,
#     'address': '1508 MARYVILLE PIKE, KNOXVILLE, TN 37920',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 47589.0,
#     'pct_no_health_ins_acs_09_13': 6.9,
#     'pct_poc': 7.58},
#    'geometry': {'type': 'Point', 'coordinates': [-83.926365, 35.919114]}},
#   {'type': 'Feature',
#    'properties': {'tract': 1900,
#     'address': 'Postal Address is unavailable for the Site, CHATTANOOGA, TN 37410',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 16542.0,
#     'pct_no_health_ins_acs_09_13': 9.97,
#     'pct_poc': 94.7},
#    'geometry': {'type': 'Point', 'coordinates': [-85.3162066, 35.0010118]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20605,
#     'address': 'OFF SC HWY 321, CAYCE, SC 29033',
#     'site_score': 40.7,
#     'med_hhd_inc_bg_acs_09_13': 41563.0,
#     'pct_no_health_ins_acs_09_13': 20.35,
#     'pct_poc': 24.64},
#    'geometry': {'type': 'Point', 'coordinates': [-81.0777853, 33.9302095]}},
#   {'type': 'Feature',
#    'properties': {'tract': 970300,
#     'address': '100 CLINTON ST, BARNWELL, SC 29812',
#     'site_score': 68.26,
#     'med_hhd_inc_bg_acs_09_13': 26765.0,
#     'pct_no_health_ins_acs_09_13': 10.22,
#     'pct_poc': 77.9},
#    'geometry': {'type': 'Point', 'coordinates': [-81.3774849, 33.2404269]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11407,
#     'address': 'STATE ROUTE 53 &amp; I-20, PONTIAC, SC 29045',
#     'site_score': 35.94,
#     'med_hhd_inc_bg_acs_09_13': 63250.0,
#     'pct_no_health_ins_acs_09_13': 11.98,
#     'pct_poc': 30.480000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8548092, 34.1284842]}},
#   {'type': 'Feature',
#    'properties': {'tract': 2301,
#     'address': '3335 OLD BUNCOMBE ROAD, GREENVILLE, SC 29617',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 35962.0,
#     'pct_no_health_ins_acs_09_13': 32.36,
#     'pct_poc': 27.14},
#    'geometry': {'type': 'Point', 'coordinates': [-82.426098, 34.8828419]}},
#   {'type': 'Feature',
#    'properties': {'tract': 501,
#     'address': 'US HWY 21 N OF AIR BASE, BURTON, SC 29902',
#     'site_score': 47.7,
#     'med_hhd_inc_bg_acs_09_13': 36280.0,
#     'pct_no_health_ins_acs_09_13': 28.52,
#     'pct_poc': 75.36000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-80.7239954, 32.4357481]}},
#   {'type': 'Feature',
#    'properties': {'tract': 960502,
#     'address': 'GLENN SPRINGS RD, LAWRENCEBURG, TN 38464',
#     'site_score': 46.44,
#     'med_hhd_inc_bg_acs_09_13': 56486.0,
#     'pct_no_health_ins_acs_09_13': 9.35,
#     'pct_poc': 2.38},
#    'geometry': {'type': 'Point', 'coordinates': [-87.3756653, 35.225524]}},
#   {'type': 'Feature',
#    'properties': {'tract': 207102,
#     'address': 'POLLOCK WELLFIELD, LOS ANGELES, CA 90086',
#     'site_score': 35.57,
#     'med_hhd_inc_bg_acs_09_13': 12647.0,
#     'pct_no_health_ins_acs_09_13': 32.46,
#     'pct_poc': 96.95},
#    'geometry': {'type': 'Point', 'coordinates': [-118.24, 34.06]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20200,
#     'address': '44CSC/DE, ELLSWORTH AFB, SD 57706',
#     'site_score': 33.62,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 29.499999999999996},
#    'geometry': {'type': 'Point', 'coordinates': [-103.0901656, 44.1538145]}},
#   {'type': 'Feature',
#    'properties': {'tract': 966600,
#     'address': '4 MILES SE OF LEAD, LEAD, SD 57754',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 66300.0,
#     'pct_no_health_ins_acs_09_13': 13.15,
#     'pct_poc': 9.4},
#    'geometry': {'type': 'Point', 'coordinates': [-103.7396972, 44.3512138]}},
#   {'type': 'Feature',
#    'properties': {'tract': 961100,
#     'address': 'SOUTH BELLS STREET, ALAMO, TN 38001',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 31926.0,
#     'pct_no_health_ins_acs_09_13': 23.04,
#     'pct_poc': 29.839999999999996},
#    'geometry': {'type': 'Point', 'coordinates': [-89.1171366, 35.7770239]}},
#   {'type': 'Feature',
#    'properties': {'tract': 800,
#     'address': 'MEADOW ST, JACKSON, TN 38301',
#     'site_score': 35.22,
#     'med_hhd_inc_bg_acs_09_13': 9617.0,
#     'pct_no_health_ins_acs_09_13': 10.29,
#     'pct_poc': 67.69000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-88.8326375, 35.6110476]}},
#   {'type': 'Feature',
#    'properties': {'tract': 20900,
#     'address': '12121 HWY 70, ARLINGTON, TN 38002',
#     'site_score': 39.03,
#     'med_hhd_inc_bg_acs_09_13': 100125.0,
#     'pct_no_health_ins_acs_09_13': 4.19,
#     'pct_poc': 17.42},
#    'geometry': {'type': 'Point', 'coordinates': [-89.6581094, 35.3002191]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21520,
#     'address': '97 S BYHALIA RD, COLLIERVILLE, TN 38017',
#     'site_score': 48.91,
#     'med_hhd_inc_bg_acs_09_13': 97961.0,
#     'pct_no_health_ins_acs_09_13': 8.37,
#     'pct_poc': 44.38999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-89.6924154, 35.041471]}},
#   {'type': 'Feature',
#    'properties': {'tract': 30800,
#     'address': '728 EMORY DRIVE, HARRIMAN, TN 37748',
#     'site_score': 48.03,
#     'med_hhd_inc_bg_acs_09_13': 19213.0,
#     'pct_no_health_ins_acs_09_13': 14.49,
#     'pct_poc': 9.770000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-84.5445165, 35.9299722]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7400,
#     'address': '3517 Southern Avenue, MEMPHIS, TN 38111',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 28259.0,
#     'pct_no_health_ins_acs_09_13': 16.98,
#     'pct_poc': 30.06},
#    'geometry': {'type': 'Point', 'coordinates': [-89.9450191, 35.1150104]}},
#   {'type': 'Feature',
#    'properties': {'tract': 950200,
#     'address': 'BELEW DRIVE, WAYNESBORO, TN 38485',
#     'site_score': 29.44,
#     'med_hhd_inc_bg_acs_09_13': 27429.0,
#     'pct_no_health_ins_acs_09_13': 12.27,
#     'pct_poc': 2.39},
#    'geometry': {'type': 'Point', 'coordinates': [-87.7596742, 35.3184212]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7810,
#     'address': '2163 AIRWAYS BLVD, MEMPHIS, TN 38114',
#     'site_score': 58.06,
#     'med_hhd_inc_bg_acs_09_13': 14044.0,
#     'pct_no_health_ins_acs_09_13': 16.08,
#     'pct_poc': 97.94},
#    'geometry': {'type': 'Point', 'coordinates': [-89.9887654, 35.0872256]}},
#   {'type': 'Feature',
#    'properties': {'tract': 432700,
#     'address': 'PECK RD &amp; REAL, EL MONTE, CA 91733',
#     'site_score': 42.24,
#     'med_hhd_inc_bg_acs_09_13': 39035.0,
#     'pct_no_health_ins_acs_09_13': 29.98,
#     'pct_poc': 97.41000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0213098, 34.0772285]}},
#   {'type': 'Feature',
#    'properties': {'tract': 966400,
#     'address': 'HWY 104, MILAN, TN 38358',
#     'site_score': 58.15,
#     'med_hhd_inc_bg_acs_09_13': 30859.0,
#     'pct_no_health_ins_acs_09_13': 18.44,
#     'pct_poc': 14.52},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7582846, 35.9202372]}},
#   {'type': 'Feature',
#    'properties': {'tract': 980100,
#     'address': 'BETHEL VALLEY ROAD, OAK RIDGE, TN 37830',
#     'site_score': 51.13,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [-84.2643233, 35.9587597]}},
#   {'type': 'Feature',
#    'properties': {'tract': 60702,
#     'address': '100 N RAILROAD STREET, ROSSVILLE, TN 38066',
#     'site_score': 37.65,
#     'med_hhd_inc_bg_acs_09_13': 47422.0,
#     'pct_no_health_ins_acs_09_13': 7.94,
#     'pct_poc': 43.61000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-89.547471, 35.0487806]}},
#   {'type': 'Feature',
#    'properties': {'tract': 950100,
#     'address': 'TOONE-TEAGUE RD, TOONE, TN 38381',
#     'site_score': 47.71,
#     'med_hhd_inc_bg_acs_09_13': 47825.0,
#     'pct_no_health_ins_acs_09_13': 26.22,
#     'pct_poc': 23.84},
#    'geometry': {'type': 'Point', 'coordinates': [-88.919439, 35.4053119]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21620,
# ...
#     'pct_poc': 48.81999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-74.4116754, 40.5756393]}},
#   {'type': 'Feature',
#    'properties': {'tract': 700900,
#     'address': 'CHERRY STREET, BEVERLY, NJ 08010',
#     'site_score': 33.86,
#     'med_hhd_inc_bg_acs_09_13': 61800.0,
#     'pct_no_health_ins_acs_09_13': 16.4,
#     'pct_poc': 29.980000000000004},
#    'geometry': {'type': 'Point', 'coordinates': [-74.9246255, 40.059158]}},
#   {'type': 'Feature',
#    'properties': {'tract': 16201,
#     'address': 'NEAR RT 101, MILFORD, NH 03055',
#     'site_score': 37.52,
#     'med_hhd_inc_bg_acs_09_13': 82500.0,
#     'pct_no_health_ins_acs_09_13': 5.59,
#     'pct_poc': 5.7299999999999995},
#    'geometry': {'type': 'Point', 'coordinates': [-71.6725998, 42.82874]}},
#   {'type': 'Feature',
#    'properties': {'tract': 83002,
#     'address': 'BLACKWATER RD, SOMERSWORTH, NH 03878',
#     'site_score': 65.56,
#     'med_hhd_inc_bg_acs_09_13': 39688.0,
#     'pct_no_health_ins_acs_09_13': 7.4,
#     'pct_poc': 7.8100000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-70.8992923, 43.2453899]}},
#   {'type': 'Feature',
#    'properties': {'tract': 23000,
#     'address': 'RT. 202, PETERBOROUGH, NH 03458',
#     'site_score': 35.64,
#     'med_hhd_inc_bg_acs_09_13': 55950.0,
#     'pct_no_health_ins_acs_09_13': 5.66,
#     'pct_poc': 4.2},
#    'geometry': {'type': 'Point', 'coordinates': [-71.9515197, 42.8705345]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11401,
#     'address': 'GILSON RD, NASHUA, NH 03062',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 114878.0,
#     'pct_no_health_ins_acs_09_13': 3.7800000000000002,
#     'pct_poc': 23.07},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5235409, 42.7180274]}},
#   {'type': 'Feature',
#    'properties': {'tract': 373100,
#     'address': '44 STATION ROAD, SPARTA TOWNSHIP, NJ 07871',
#     'site_score': 28.91,
#     'med_hhd_inc_bg_acs_09_13': 138125.0,
#     'pct_no_health_ins_acs_09_13': 3.93,
#     'pct_poc': 13.049999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-74.6304831, 41.0472225]}},
#   {'type': 'Feature',
#    'properties': {'tract': 50703,
#     'address': 'EASTON TURNPIKE, BOUND BROOK, NJ 08805',
#     'site_score': 50.28,
#     'med_hhd_inc_bg_acs_09_13': 155714.0,
#     'pct_no_health_ins_acs_09_13': 5.34,
#     'pct_poc': 53.099999999999994},
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.6622416, 40.593780699999996]}},
#   {'type': 'Feature',
#    'properties': {'tract': 9200,
#     'address': '120 HORSESHOE ROAD, SAYREVILLE, NJ 08872',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 96699.0,
#     'pct_no_health_ins_acs_09_13': 2.5300000000000002,
#     'pct_poc': 42.63},
#    'geometry': {'type': 'Point', 'coordinates': [-74.3182342, 40.4793542]}},
#   {'type': 'Feature',
#    'properties': {'tract': 811502,
#     'address': 'SQUANRUM RD. (MONMOUTH CO. RT. 547), HOWELL TOWNSHIP, NJ 07727',
#     'site_score': 43.23,
#     'med_hhd_inc_bg_acs_09_13': 105515.0,
#     'pct_no_health_ins_acs_09_13': 9.68,
#     'pct_poc': 11.94},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1592278, 40.1940632]}},
#   {'type': 'Feature',
#    'properties': {'tract': 713202,
#     'address': 'SALLY IKE ROAD, BRICK TOWNSHIP, NJ 08723',
#     'site_score': 58.13,
#     'med_hhd_inc_bg_acs_09_13': 83669.0,
#     'pct_no_health_ins_acs_09_13': 12.05,
#     'pct_poc': 10.389999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1224679, 40.1146537]}},
#   {'type': 'Feature',
#    'properties': {'tract': 51200,
#     'address': '100 WEST MAIN STREET, BOUND BROOK, NJ 08805',
#     'site_score': 58.12,
#     'med_hhd_inc_bg_acs_09_13': 40638.0,
#     'pct_no_health_ins_acs_09_13': 31.0,
#     'pct_poc': 71.12},
#    'geometry': {'type': 'Point', 'coordinates': [-74.5367909, 40.559824]}},
#   {'type': 'Feature',
#    'properties': {'tract': 809501,
#     'address': 'TYLERS LANE, MARLBORO TOWNSHIP, NJ 07746',
#     'site_score': 59.16,
#     'med_hhd_inc_bg_acs_09_13': 122643.0,
#     'pct_no_health_ins_acs_09_13': 6.03,
#     'pct_poc': 31.119999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-74.2758044, 40.3737485]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21601,
#     'address': '222 PASSAIC AVENUE, FAIRFIELD, NJ 07004',
#     'site_score': 58.3,
#     'med_hhd_inc_bg_acs_09_13': 115192.0,
#     'pct_no_health_ins_acs_09_13': 8.42,
#     'pct_poc': 12.42},
#    'geometry': {'type': 'Point', 'coordinates': [-74.272773, 40.8776359]}},
#   {'type': 'Feature',
#    'properties': {'tract': 30600,
#     'address': '23 SOUTH FRONT ST, ELIZABETH, NJ 07202',
#     'site_score': 47.13,
#     'med_hhd_inc_bg_acs_09_13': 43393.0,
#     'pct_no_health_ins_acs_09_13': 30.63,
#     'pct_poc': 78.09},
#    'geometry': {'type': 'Point', 'coordinates': [-74.2016192, 40.6362966]}},
#   {'type': 'Feature',
#    'properties': {'tract': 1701,
#     'address': '30 WHITMAN AV, EDISON TOWNSHIP, NJ 08817',
#     'site_score': 37.93,
#     'med_hhd_inc_bg_acs_09_13': 109583.0,
#     'pct_no_health_ins_acs_09_13': 3.46,
#     'pct_poc': 36.900000000000006},
#    'geometry': {'type': 'Point', 'coordinates': [-74.3737943, 40.5283009]}},
#   {'type': 'Feature',
#    'properties': {'tract': 502400,
#     'address': 'CEDAR SWAMP &amp; COOPER RDS, BRIDGEPORT, NJ 08014',
#     'site_score': 47.53,
#     'med_hhd_inc_bg_acs_09_13': 67159.0,
#     'pct_no_health_ins_acs_09_13': 5.44,
#     'pct_poc': 4.82},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3478016, 39.8004233]}},
#   {'type': 'Feature',
#    'properties': {'tract': 502,
#     'address': 'FLEMING ST, PISCATAWAY, NJ 08854',
#     'site_score': 42.69,
#     'med_hhd_inc_bg_acs_09_13': 87708.0,
#     'pct_no_health_ins_acs_09_13': 17.17,
#     'pct_poc': 73.69},
#    'geometry': {'type': 'Point', 'coordinates': [-74.4465827, 40.5619457]}},
#   {'type': 'Feature',
#    'properties': {'tract': 4715,
#     'address': '6200 PERKINS, OXNARD, CA 93033',
#     'site_score': 58.31,
#     'med_hhd_inc_bg_acs_09_13': 46228.0,
#     'pct_no_health_ins_acs_09_13': 24.5,
#     'pct_poc': 84.17999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-119.1839744, 34.1401543]}},
#   {'type': 'Feature',
#    'properties': {'tract': 4409,
#     'address': '7140 N HARRISON, FRESNO, CA 93650',
#     'site_score': 51.13,
#     'med_hhd_inc_bg_acs_09_13': 51736.0,
#     'pct_no_health_ins_acs_09_13': 23.37,
#     'pct_poc': 52.16},
#    'geometry': {'type': 'Point', 'coordinates': [-119.8104233, 36.8422612]}},
#   {'type': 'Feature',
#    'properties': {'tract': 722702,
#     'address': 'RTE #37, TOMS RIVER, NJ 08753',
#     'site_score': 50.33,
#     'med_hhd_inc_bg_acs_09_13': 88534.0,
#     'pct_no_health_ins_acs_09_13': 8.32,
#     'pct_poc': 8.32},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1592278, 39.9741059]}},
#   {'type': 'Feature',
#    'properties': {'tract': 700303,
#     'address': '1017 UNION LANDING ROAD, CINNAMINSON TOWNSHIP, NJ 08077',
#     'site_score': 37.93,
#     'med_hhd_inc_bg_acs_09_13': 83857.0,
#     'pct_no_health_ins_acs_09_13': 1.28,
#     'pct_poc': 41.760000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-74.9899552, 40.0154959]}},
#   {'type': 'Feature',
#    'properties': {'tract': 45901,
#     'address': 'PARKER ROAD- BOX 418, CHESTER TOWNSHIP, NJ 07930',
#     'site_score': 45.22,
#     'med_hhd_inc_bg_acs_09_13': 101705.0,
#     'pct_no_health_ins_acs_09_13': 6.36,
#     'pct_poc': 16.849999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-74.6985891, 40.7850853]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11500,
#     'address': 'DELAWARE RIVER DR, KINGWOOD TOWNSHIP, NJ 08825',
#     'site_score': 35.72,
#     'med_hhd_inc_bg_acs_09_13': 106920.0,
#     'pct_no_health_ins_acs_09_13': 3.69,
#     'pct_poc': 3.16},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0600314, 40.4849409]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7801,
#     'address': 'WATERWORKS ROAD, OLD BRIDGE TOWNSHIP, NJ 08857',
#     'site_score': 69.73,
#     'med_hhd_inc_bg_acs_09_13': 83906.0,
#     'pct_no_health_ins_acs_09_13': 5.54,
#     'pct_poc': 35.190000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-74.3374236, 40.4273817]}},
#   {'type': 'Feature',
#    'properties': {'tract': 52200,
#     'address': '416 LANZA AVE, SADDLE BROOK TWP, NJ 07662',
#     'site_score': 34.37,
#     'med_hhd_inc_bg_acs_09_13': 59453.0,
#     'pct_no_health_ins_acs_09_13': 20.44,
#     'pct_poc': 30.889999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1033, 40.890797]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10600,
#     'address': '404 FRENCHTOWN ROAD, MILFORD, NJ 08848',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 80417.0,
#     'pct_no_health_ins_acs_09_13': 8.36,
#     'pct_poc': 3.6399999999999997},
#    'geometry': {'type': 'Point', 'coordinates': [-75.08863, 40.5621719]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11401,
#     'address': 'RTE 322, HAMILTON TOWNSHIP, NJ 08330',
#     'site_score': 55.79,
#     'med_hhd_inc_bg_acs_09_13': 63250.0,
#     'pct_no_health_ins_acs_09_13': 15.69,
#     'pct_poc': 15.09},
#    'geometry': {'type': 'Point', 'coordinates': [-74.7226761, 39.4639115]}},
#   {'type': 'Feature',
#    'properties': {'tract': 45100,
#     'address': '170 N MAIN STREET, WHARTON BOROUGH, NJ 07885',
#     'site_score': 46.13,
#     'med_hhd_inc_bg_acs_09_13': 56313.0,
#     'pct_no_health_ins_acs_09_13': 16.35,
#     'pct_poc': 49.06},
#    'geometry': {'type': 'Point', 'coordinates': [-74.57719, 40.904671]}},
#   {'type': 'Feature',
#    'properties': {'tract': 507703,
#     'address': '10900 N TANTAU AVE/19000 HOMESTEAD RD, CUPERTINO, CA 95014',
#     'site_score': 28.9,
#     'med_hhd_inc_bg_acs_09_13': 124784.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 54.79},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0723816, 37.31317]}},
#   {'type': 'Feature',
#    'properties': {'tract': 18600,
#     'address': 'GIST PLACE (NEAR NORTH DAY STREET), WEST ORANGE/ORANGE, NJ 07051',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 9670.0,
#     'pct_no_health_ins_acs_09_13': 37.26,
#     'pct_poc': 84.11},
#    'geometry': {'type': 'Point', 'coordinates': [-74.23, 40.77]}},
#   {'type': 'Feature',
#    'properties': {'tract': 511705,
#     'address': '620 - 640 PAGE MILL RD., PALO ALTO, CA 94304',
#     'site_score': 29.76,
#     'med_hhd_inc_bg_acs_09_13': 250001.0,
#     'pct_no_health_ins_acs_09_13': 3.06,
#     'pct_poc': 29.939999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-122.1437233, 37.4211945]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7501,
#     'address': '80 LISTER AVE, NEWARK, NJ 07105',
#     'site_score': 35.4,
#     'med_hhd_inc_bg_acs_09_13': 11056.0,
#     'pct_no_health_ins_acs_09_13': 18.68,
#     'pct_poc': 89.88},
#    'geometry': {'type': 'Point', 'coordinates': [-74.136117, 40.7387173]}},
#   {'type': 'Feature',
#    'properties': {'tract': 12700,
#     'address': '1401 HARRISON TURNPIKE, KEARNY, NJ 07032',
#     'site_score': 30.0,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1354652, 40.7495289]}},
#   {'type': 'Feature',
#    'properties': {'tract': 44800,
#     'address': '272 ROUTE46, DOVER, NJ 07801',
#     'site_score': 28.9,
#     'med_hhd_inc_bg_acs_09_13': 46036.0,
#     'pct_no_health_ins_acs_09_13': 48.13,
#     'pct_poc': 86.65},
#    'geometry': {'type': 'Point', 'coordinates': [-74.5434222, 40.8874674]}},
#   {'type': 'Feature',
#    'properties': {'tract': 704014,
#     'address': 'SHARP ROAD, EVESHAM TOWNSHIP, NJ 08053',
#     'site_score': 34.62,
#     'med_hhd_inc_bg_acs_09_13': 116696.0,
#     'pct_no_health_ins_acs_09_13': 6.59,
#     'pct_poc': 20.71},
#    'geometry': {'type': 'Point', 'coordinates': [-74.8659475, 39.9099693]}},
#   {'type': 'Feature',
#    'properties': {'tract': 10401,
#     'address': '128 ZURICH AVE, GALLOWAY TOWNSHIP, NJ 08215',
#     'site_score': 50.0,
#     'med_hhd_inc_bg_acs_09_13': 67155.0,
#     'pct_no_health_ins_acs_09_13': 8.45,
#     'pct_poc': 14.129999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-74.5574216, 39.4897517]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7801,
#     'address': 'OLD WATER WORKS ROAD, OLD BRIDGE TOWNSHIP, NJ 08857',
#     'site_score': 36.64,
#     'med_hhd_inc_bg_acs_09_13': 83906.0,
#     'pct_no_health_ins_acs_09_13': 5.54,
#     'pct_poc': 35.190000000000005},
#    'geometry': {'type': 'Point', 'coordinates': [-74.3374236, 40.4273817]}},
#   {'type': 'Feature',
#    'properties': {'tract': 44401,
#     'address': 'OFF RTE 15 DOVER NJ, ROCKAWAY TOWNSHIP, NJ 07801',
#     'site_score': 42.92,
#     'med_hhd_inc_bg_acs_09_13': 123306.0,
#     'pct_no_health_ins_acs_09_13': 6.49,
#     'pct_poc': 12.079999999999998},
#    'geometry': {'type': 'Point', 'coordinates': [-74.5859022, 40.9181512]}},
#   {'type': 'Feature',
#    'properties': {'tract': 7400,
#     'address': 'ONE AVENUE L, NEWARK, NJ 07105',
#     'site_score': 47.99,
#     'med_hhd_inc_bg_acs_09_13': 0.0,
#     'pct_no_health_ins_acs_09_13': 0.0,
#     'pct_poc': 90.08000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1454535, 40.7174308]}},
#   {'type': 'Feature',
#    'properties': {'tract': 32101,
#     'address': 'ROUTE 643 TO ROUTE 31, WARREN COUNTY, NJ 07882',
#     'site_score': 28.9,
#     'med_hhd_inc_bg_acs_09_13': 98309.0,
#     'pct_no_health_ins_acs_09_13': 7.41,
#     'pct_poc': 6.289999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0260667, 40.7496608]}},
#   {'type': 'Feature',
#    'properties': {'tract': 703700,
#     'address': 'WALLINGFORD WAY, SHAMONG TOWNSHIP, NJ 08088',
#     'site_score': 50.19,
#     'med_hhd_inc_bg_acs_09_13': 96613.0,
#     'pct_no_health_ins_acs_09_13': 3.5700000000000003,
#     'pct_poc': 4.859999999999999},
#    'geometry': {'type': 'Point', 'coordinates': [-74.7184367, 39.8104583]}},
#   {'type': 'Feature',
#    'properties': {'tract': 17200,
#     'address': 'IND PARK/HENDERSON BLVD 11 ST, FAIR LAWN, NJ 07410',
#     'site_score': 42.49,
#     'med_hhd_inc_bg_acs_09_13': 64417.0,
#     'pct_no_health_ins_acs_09_13': 9.2,
#     'pct_poc': 24.09},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1318096, 40.9403762]}},
#   {'type': 'Feature',
#    'properties': {'tract': 2400,
#     'address': 'ROUTES 563 &amp; 575, ATLANTIC COUNTY, NJ 08405',
#     'site_score': 39.65,
#     'med_hhd_inc_bg_acs_09_13': 23542.0,
#     'pct_no_health_ins_acs_09_13': 18.0,
#     'pct_poc': 52.46},
#    'geometry': {'type': 'Point', 'coordinates': [-74.42, 39.36]}},
#   {'type': 'Feature',
#    'properties': {'tract': 40600,
#     'address': '527 East Chestnut Avenue, VINELAND, NJ 08360',
#     'site_score': 65.29,
#     'med_hhd_inc_bg_acs_09_13': 19839.0,
#     'pct_no_health_ins_acs_09_13': 12.68,
#     'pct_poc': 85.43},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0260838, 39.4784365]}},
#   {'type': 'Feature',
#    'properties': {'tract': 501703,
#     'address': 'SIX LOCATIONS NEAR MARSHALL MILL ROAD, FRANKLIN TOWNSHIP, NJ 08322',
#     'site_score': 40.67,
#     'med_hhd_inc_bg_acs_09_13': 61563.0,
#     'pct_no_health_ins_acs_09_13': 20.23,
#     'pct_poc': 11.32},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0630275, 39.5952969]}},
#   {'type': 'Feature',
#    'properties': {'tract': 6601,
#     'address': '11 FRESH POND ROAD, EAST BRUNSWICK TOWNSHIP, NJ 08816',
#     'site_score': 33.61,
#     'med_hhd_inc_bg_acs_09_13': 106042.0,
#     'pct_no_health_ins_acs_09_13': 8.39,
#     'pct_poc': 20.25},
#    'geometry': {'type': 'Point', 'coordinates': [-74.440511, 40.4426077]}},
#   {'type': 'Feature',
#    'properties': {'tract': 11300,
#     'address': 'SUMMER ROAD, P.O. BOX 183, MINOTOLA, NJ 08341',
#     'site_score': 28.9,
#     'med_hhd_inc_bg_acs_09_13': 40093.0,
#     'pct_no_health_ins_acs_09_13': 7.4,
#     'pct_poc': 28.449999999999996},
#    'geometry': {'type': 'Point', 'coordinates': [-74.952142, 39.519117]}},
#   {'type': 'Feature',
#    'properties': {'tract': 21600,
#     'address': 'WILLARD STREET AND PIERRE AVENUE, GARFIELD, NJ 07026',
#     'site_score': 0.0,
#     'med_hhd_inc_bg_acs_09_13': 55139.0,
#     'pct_no_health_ins_acs_09_13': 24.86,
#     'pct_poc': 54.56},
#    'geometry': {'type': 'Point', 'coordinates': [-74.1066416, 40.8718863]}},
#   ...]}

# %%
output_filename = geojson_output_file
with open(output_filename, 'w') as output_file:
    # optional line for defining a variable here
    # output_file.write('var dataset = ')
    json.dump(geojson, output_file, indent=2)

# %% [markdown]
# ### Export as a flat JSON

# %%
superfund_sites_for_viz.to_json(r'../03_Dataset/superfund_site_json.json', orient='records')

# %%
superfund_sites_for_viz.columns.values
# Out:
# array(['id', 'address', 'city', 'latitude', 'longitude', 'site_score',
#        'state_name', 'county_name', 'tract', 'block_group',
#        'tot_population_cen_2010', 'hispanic_cen_2010',
#        'nh_blk_alone_cen_2010', 'nh_aian_alone_cen_2010',
#        'nh_asian_alone_cen_2010', 'nh_nhopi_alone_cen_2010',
#        'nh_sor_alone_cen_2010', 'college_acs_09_13',
#        'no_health_ins_acs_09_13', 'med_hhd_inc_bg_acs_09_13',
#        'aggregate_hh_inc_acs_09_13', 'tot_vacant_units_cen_2010',
#        'renter_occp_hu_cen_2010', 'owner_occp_hu_cen_2010',
#        'no_plumb_acs_09_13', 'med_house_value_bg_acs_09_13',
#        'pct_hispanic_cen_2010', 'pct_nh_blk_alone_cen_2010',
#        'pct_nh_aian_alone_cen_2010', 'pct_nh_asian_alone_cen_2010',
#        'pct_nh_nhopi_alone_cen_2010', 'pct_nh_sor_alone_cen_2010',
#        'pct_not_hs_grad_acs_09_13', 'pct_no_health_ins_acs_09_13',
#        'pct_vacant_units_cen_2010', 'pct_renter_occp_hu_cen_2010',
#        'pct_owner_occp_hu_cen_2010', 'pct_no_plumb_acs_09_13', 'pct_poc'],
#       dtype=object)
